# %% [markdown]
# ### Input
#
# detected pattern patternlist.xlsx
#
# tagged named entities (chemical, gene and fuzzy"O") train0_truth.tsv
#
# ### Output
#
# confidence of patterns and named entities
#
# Then evaluate them by the matching them to train1.ner.txt
#
# ### data location
#
# tagged file from fuzzy-ner: /shared/data/shizhi2/data_fuzzyCRF/case/train0_all.tsv, train1_all.tsv (edited) **train0_gene.tsv**, **train1_chem.tsv**
#
# ground truth: /shared/data/shizhi2/data_fuzzyCRF/bio-ner/**train0_all.tsv**, **train1_all.tsv** contain all the gene and chemical labels
#
# patternlist: **patternlist.xlsx**

# %%
import pandas as pd
import numpy as np
import re
import nltk
from textblob import TextBlob

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/flyingturtle/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# S-GENE single
#
# B-GENE begining of the gene
#
# E-GENE end of the gene

# %% [markdown]
# # Context Patterns

# %%
named_entity_list = {}
with open("train1_all.tsv", "r") as f:
    for line in f:
        segs = line[:-1].split("\t")
        named_entity = " ".join(segs[:-1])
        entity_label = segs[-1]
        
        # check if there is a collision
        try:
            if(named_entity_list[named_entity]):
                pass
        except:
            named_entity_list[named_entity] = [entity_label]
            
        if(entity_label != "O" and entity_label not in named_entity_list[named_entity]):
            named_entity_list[named_entity].append(entity_label)

print("number of named entities with labels: ", len(named_entity_list.keys()))
# Out:
# number of named entities with labels:  43135

# %%
pattern_list = pd.read_excel("patternlist.xlsx", header=None, names=["id", "pattern"])
print(pattern_list.head())
print(len(pattern_list))
# Out:
#             id                           pattern
# 0    PATTERN10                  CHEMICAL therapy
# 1   PATTERN100  transcriptional activity of GENE
# 2  PATTERN1001               100 microm CHEMICAL
# 3  PATTERN1003               activity in DISEASE
# 4  PATTERN1005             the DISEASE cell line
# 4780

# %%
with open("train1.ner.txt") as f:
    whole_context = f.read()
    context_segs = whole_context.split("\n")

# %%
context_segs[:5]
# Out:
# ['Effect of CHEMICAL_D002994_clofibrate on plasma proteins including components of the hemostatic mechanism.',
#  'The effect of CHEMICAL_D002994_clofibrate (1.5 g/day) on different plasma proteins and on components of the hemostatic system was studied in eight SPECIES_9606_men with either mild DISEASE_D003920_diabetes_mellitus or cardiosclerosis.',
#  'Before treatment, the subjects were investigated weekly on five occasions.',
#  'The means of these determinations were compared with the values observed after 2, 6 and 14 weeks of treatment.',
#  'During the treatment albumin and GENE_7018_transferrin increased significantly while orosomucoid, ceruloplasmin, beta1 E-globulin, IgA, IgM and fibrinogen decreased significantly.']

# %%
def pmatch(pattern, document):
    """
    This function matchs a pattern containing "CHEMICAL", "GENE", "DISEASE" to a given document
    """
    
    res = {"content": pattern, "matches":[]}
    
    # generate re query for search
    match_query = re.sub('CHEMICAL|GENE|DISEASE', "(.*?)", pattern)
    if(match_query[-5:]=="(.*?)"):
        match_query = match_query[:-5] + "(.*)"
        
    # search pattern in the document
    matches = re.search(match_query, document)
    pos_pattern = list(re.finditer("CHEMICAL|GENE|DISEASE", pattern))
    
    index = 1
    for p in pos_pattern[:-1]:
        res["matches"].append((p.group(0), matches.group(index)))
        index += 1
    tail = matches.group(index).split(" ")
    if(tail[0] in ["the", "a", "in"]):
        last_word = tail[1]
    else:
        last_word = tail[0]
    res["matches"].append((pos_pattern[-1].group(0), last_word))
    
    return res

    
    
pmatch("development of DISEASE such as GENE will DISEASE", "The development of the last proteins such as we will king of all the issue")
# Out:
# {'content': 'development of DISEASE such as GENE will DISEASE',
#  'matches': [('DISEASE', 'the last proteins'),
#   ('GENE', 'we'),
#   ('DISEASE', 'king')]}

# %%
from textblob import TextBlob
txt = """king of all the issue"""
blob = TextBlob(txt)
print(blob.noun_phrases)
# Out:
# []

# %%
for inex, row in pattern_list.iterrows():
    pattern = row["pattern"]
    print(pattern)
    try: # in case pattern == "nan"
        print(re.split('CHEMICAL|GENE|DISEASE|\n',pattern))
    except:
        pass
# Out:
# CHEMICAL therapy
# ['', ' therapy']
# transcriptional activity of GENE
# ['transcriptional activity of ', '']
# 100 microm CHEMICAL
# ['100 microm ', '']
# activity in DISEASE
# ['activity in ', '']
# the DISEASE cell line
# ['the ', ' cell line']
# transcription of GENE
# ['transcription of ', '']
# a metabolite of CHEMICAL
# ['a metabolite of ', '']
# similar DISEASE
# ['similar ', '']
# nuclear CHEMICAL
# ['nuclear ', '']
# SPECIES disease
# ['SPECIES disease']
# aged SPECIES
# ['aged SPECIES']
# CHEMICAL ( pb )
# ['', ' ( pb )']
# CHEMICAL pump
# ['', ' pump']
# SPECIES heart
# ['SPECIES heart']
# enos and GENE
# ['enos and ', '']
# GENE protein abundance
# ['', ' protein abundance']
# DISEASE lung
# ['', ' lung']
# GENE activation
# ['', ' activation']
# regulation of CHEMICAL
# ['regulation of ', '']
# GENE neuron
# ['', ' neuron']
# GENE messenger rna ( mrna )
# ['', ' messenger rna ( mrna )']
# CHEMICAL injection (
# ['', ' injection (']
# relative to GENE
# ['relative to ', '']
# CHEMICAL side
# ['', ' side']
# the regulation of GENE
# ['the regulation of ', '']
# constitutive expression of GENE
# ['constitutive expression of ', '']
# GENE transcription
# ['', ' transcription']
# the protective action of CHEMICAL
# ['the protective action of ', '']
# the protection against DISEASE
# ['the protection against ', '']
# CHEMICAL mobilization
# ['', ' mobilization']
# the mrna expression of GENE
# ['the mrna expression of ', '']
# the in vitro effect of CHEMICAL
# ['the in vitro effect of ', '']
# CHEMICAL ( ppm )
# ['', ' ( ppm )']
# intact SPECIES
# ['intact SPECIES']
# nan
# an GENE
# ['an ', '']
# morphological DISEASE
# ['morphological ', '']
# CHEMICAL neuron
# ['', ' neuron']
# GENE response
# ['', ' response']
# GENE cdna
# ['', ' cdna']
# decrease GENE
# ['decrease ', '']
# plasma CHEMICAL level
# ['plasma ', ' level']
# CHEMICAL ( ne )
# ['', ' ( ne )']
# production of GENE
# ['production of ', '']
# systemic administration of CHEMICAL
# ['systemic administration of ', '']
# brown SPECIES
# ['brown SPECIES']
# lewis SPECIES
# ['lewis SPECIES']
# the interaction of CHEMICAL
# ['the interaction of ', '']
# DISEASE case
# ['', ' case']
# CHEMICAL reuptake
# ['', ' reuptake']
# the acute DISEASE
# ['the acute ', '']
# persistent DISEASE
# ['persistent ', '']
# recurrence of DISEASE
# ['recurrence of ', '']
# DISEASE symptom
# ['', ' symptom']
# GENE activity
# ['', ' activity']
# SPECIES and animal
# ['SPECIES and animal']
# weight CHEMICAL
# ['weight ', '']
# CHEMICAL nephrotoxicity
# ['', ' nephrotoxicity']
# CHEMICAL dismutase ( sod ) , catalase
# ['', ' dismutase ( sod ) , catalase']
# hepatic CHEMICAL concentration
# ['hepatic ', ' concentration']
# sod and CHEMICAL
# ['sod and ', '']
# serum GENE
# ['serum ', '']
# CHEMICAL incorporation
# ['', ' incorporation']
# GENE treatment
# ['', ' treatment']
# CHEMICAL analog
# ['', ' analog']
# DISEASE control
# ['', ' control']
# microm CHEMICAL
# ['microm ', '']
# the DISEASE group
# ['the ', ' group']
# CHEMICAL incubation
# ['', ' incubation']
# CHEMICAL activation
# ['', ' activation']
# the CHEMICAL chelator
# ['the ', ' chelator']
# the antioxidant CHEMICAL
# ['the antioxidant ', '']
# SPECIES neutrophil
# ['SPECIES neutrophil']
# incubation of SPECIES
# ['incubation of SPECIES']
# CHEMICAL ( 100 nm )
# ['', ' ( 100 nm )']
# 10 microm CHEMICAL
# ['10 microm ', '']
# CHEMICAL accumulation
# ['', ' accumulation']
# tissue GENE
# ['tissue ', '']
# alteration of GENE
# ['alteration of ', '']
# the CHEMICAL kinase
# ['the ', ' kinase']
# CHEMICAL buffer
# ['', ' buffer']
# CHEMICAL retention
# ['', ' retention']
# DISEASE induction
# ['', ' induction']
# cell GENE
# ['cell ', '']
# sensitivity of SPECIES
# ['sensitivity of SPECIES']
# urinary CHEMICAL
# ['urinary ', '']
# CHEMICAL medium
# ['', ' medium']
# intracellular CHEMICAL accumulation
# ['intracellular ', ' accumulation']
# the reactive CHEMICAL specie
# ['the reactive ', ' specie']
# 10 nm CHEMICAL
# ['10 nm ', '']
# CHEMICAL , substrate
# ['', ' , substrate']
# CHEMICAL cyclohydrolase
# ['', ' cyclohydrolase']
# SPECIES prostate
# ['SPECIES prostate']
# autophosphorylation of GENE
# ['autophosphorylation of ', '']
# a DISEASE model
# ['a ', ' model']
# metabolite of CHEMICAL
# ['metabolite of ', '']
# the exception of CHEMICAL
# ['the exception of ', '']
# the inhibitory effect of CHEMICAL
# ['the inhibitory effect of ', '']
# CHEMICAL radical scavenger
# ['', ' radical scavenger']
# DISEASE production
# ['', ' production']
# the most common DISEASE
# ['the most common ', '']
# potent GENE
# ['potent ', '']
# the role of GENE
# ['the role of ', '']
# intracellular CHEMICAL concentration
# ['intracellular ', ' concentration']
# GENE subunit
# ['', ' subunit']
# SPECIES oocyte
# ['SPECIES oocyte']
# low CHEMICAL concentration
# ['low ', ' concentration']
# CHEMICAL kinase ,
# ['', ' kinase ,']
# downregulation of GENE
# ['downregulation of ', '']
# no change in GENE
# ['no change in ', '']
# the amount of GENE
# ['the amount of ', '']
# GENE autophosphorylation
# ['', ' autophosphorylation']
# GENE protein
# ['', ' protein']
# the activation of DISEASE
# ['the activation of ', '']
# dermal DISEASE
# ['dermal ', '']
# water and CHEMICAL
# ['water and ', '']
# hypothalamic GENE
# ['hypothalamic ', '']
# 50 microm CHEMICAL
# ['50 microm ', '']
# unconjugated CHEMICAL
# ['unconjugated ', '']
# the GENE kinase
# ['the ', ' kinase']
# GENE isozyme
# ['', ' isozyme']
# chronic CHEMICAL exposure
# ['chronic ', ' exposure']
# f344 SPECIES
# ['f344 SPECIES']
# one DISEASE
# ['one ', '']
# normal SPECIES keratinocyte
# ['normal SPECIES keratinocyte']
# the GENE expression
# ['the ', ' expression']
# CHEMICAL , drug
# ['', ' , drug']
# impair DISEASE
# ['impair ', '']
# CHEMICAL and metabolite
# ['', ' and metabolite']
# CHEMICAL potentiate
# ['', ' potentiate']
# 200 microm CHEMICAL
# ['200 microm ', '']
# CHEMICAL finger
# ['', ' finger']
# other GENE inhibitor
# ['other ', ' inhibitor']
# DISEASE event
# ['', ' event']
# 4 SPECIES
# ['4 SPECIES']
# susceptibility to DISEASE
# ['susceptibility to ', '']
# CHEMICAL detoxification
# ['', ' detoxification']
# risk of DISEASE
# ['risk of ', '']
# regression of DISEASE
# ['regression of ', '']
# CHEMICAL level and
# ['', ' level and']
# GENE function
# ['', ' function']
# alteration in GENE
# ['alteration in ', '']
# stimulation of CHEMICAL
# ['stimulation of ', '']
# inhibition by CHEMICAL
# ['inhibition by ', '']
# both GENE expression
# ['both ', ' expression']
# ( GENE ) activity
# ['( ', ' ) activity']
# GENE expression ,
# ['', ' expression ,']
# CHEMICAL ratio
# ['', ' ratio']
# the effect of CHEMICAL
# ['the effect of ', '']
# a subgroup of SPECIES
# ['a subgroup of SPECIES']
# gene expression of GENE
# ['gene expression of ', '']
# the GENE oncogene
# ['the ', ' oncogene']
# DISEASE research
# ['', ' research']
# addition to DISEASE
# ['addition to ', '']
# surface expression of GENE
# ['surface expression of ', '']
# SPECIES volunteer
# ['SPECIES volunteer']
# 12 SPECIES
# ['12 SPECIES']
# a GENE inhibitor ,
# ['a ', ' inhibitor ,']
# SPECIES airway
# ['SPECIES airway']
# the elevation of CHEMICAL
# ['the elevation of ', '']
# novo CHEMICAL
# ['novo ', '']
# SPECIES development
# ['SPECIES development']
# SPECIES skin
# ['SPECIES skin']
# mammary DISEASE
# ['mammary ', '']
# serum CHEMICAL
# ['serum ', '']
# an inhibitor of CHEMICAL
# ['an inhibitor of ', '']
# the survival rate of SPECIES
# ['the survival rate of SPECIES']
# massive DISEASE
# ['massive ', '']
# CHEMICAL and receptor
# ['', ' and receptor']
# this effect of CHEMICAL
# ['this effect of ', '']
# a mechanism of DISEASE
# ['a mechanism of ', '']
# fetal SPECIES
# ['fetal SPECIES']
# the DISEASE risk
# ['the ', ' risk']
# the addition of CHEMICAL
# ['the addition of ', '']
# GENE formation
# ['', ' formation']
# condition of DISEASE
# ['condition of ', '']
# CHEMICAL receptor activation
# ['', ' receptor activation']
# the DISEASE cell
# ['the ', ' cell']
# DISEASE cell differentiation
# ['', ' cell differentiation']
# control and CHEMICAL
# ['control and ', '']
# CHEMICAL release ,
# ['', ' release ,']
# drug and CHEMICAL
# ['drug and ', '']
# heterocyclic CHEMICAL
# ['heterocyclic ', '']
# DISEASE examine
# ['', ' examine']
# incorporation of CHEMICAL
# ['incorporation of ', '']
# protection from DISEASE
# ['protection from ', '']
# the synthesis of CHEMICAL
# ['the synthesis of ', '']
# DISEASE cell line
# ['', ' cell line']
# DISEASE response
# ['', ' response']
# DISEASE increase
# ['', ' increase']
# a high risk of DISEASE
# ['a high risk of ', '']
# DISEASE line
# ['', ' line']
# hyperphosphorylation of GENE
# ['hyperphosphorylation of ', '']
# the DISEASE tissue
# ['the ', ' tissue']
# a DISEASE suppressor gene
# ['a ', ' suppressor gene']
# SPECIES macrophage
# ['SPECIES macrophage']
# exposure of SPECIES
# ['exposure of SPECIES']
# CHEMICAL ionophore
# ['', ' ionophore']
# DISEASE cell
# ['', ' cell']
# DISEASE necrosis
# ['', ' necrosis']
# the GENE transcript
# ['the ', ' transcript']
# intracellular CHEMICAL level
# ['intracellular ', ' level']
# the availability of CHEMICAL
# ['the availability of ', '']
# DISEASE exhibit
# ['', ' exhibit']
# inactivation of GENE
# ['inactivation of ', '']
# homozygous SPECIES
# ['homozygous SPECIES']
# mechanism of DISEASE
# ['mechanism of ', '']
# CHEMICAL transport ,
# ['', ' transport ,']
# immature female SPECIES
# ['immature female SPECIES']
# the GENE gene
# ['the ', ' gene']
# the estrogenic effect of CHEMICAL
# ['the estrogenic effect of ', '']
# selective GENE
# ['selective ', '']
# the inhibition by CHEMICAL
# ['the inhibition by ', '']
# CHEMICAL cyclase
# ['', ' cyclase']
# CHEMICAL inhibition
# ['', ' inhibition']
# expression by CHEMICAL
# ['expression by ', '']
# the use of CHEMICAL
# ['the use of ', '']
# respect to CHEMICAL
# ['respect to ', '']
# intracellular CHEMICAL
# ['intracellular ', '']
# 18 SPECIES
# ['18 SPECIES']
# CHEMICAL in vivo
# ['', ' in vivo']
# the biological effect of CHEMICAL
# ['the biological effect of ', '']
# contrast to CHEMICAL
# ['contrast to ', '']
# CHEMICAL status
# ['', ' status']
# the removal of CHEMICAL
# ['the removal of ', '']
# disruption of GENE
# ['disruption of ', '']
# sporadic DISEASE
# ['sporadic ', '']
# GENE overexpression
# ['', ' overexpression']
# the inhibitor CHEMICAL
# ['the inhibitor ', '']
# DISEASE treatment
# ['', ' treatment']
# GENE receptor gene
# ['', ' receptor gene']
# CHEMICAL on cell
# ['', ' on cell']
# recombinant SPECIES
# ['recombinant SPECIES']
# GENE alone
# ['', ' alone']
# GENE expression
# ['', ' expression']
# marked DISEASE
# ['marked ', '']
# CHEMICAL dismutase ( sod ) and catalase
# ['', ' dismutase ( sod ) and catalase']
# ( CHEMICAL ) level
# ['( ', ' ) level']
# CHEMICAL level (
# ['', ' level (']
# CHEMICAL ingestion
# ['', ' ingestion']
# serum CHEMICAL level
# ['serum ', ' level']
# the effect on GENE
# ['the effect on ', '']
# role of CHEMICAL
# ['role of ', '']
# CHEMICAL stress
# ['', ' stress']
# evidence of DISEASE
# ['evidence of ', '']
# adult DISEASE
# ['adult ', '']
# arterial DISEASE
# ['arterial ', '']
# DISEASE weight
# ['', ' weight']
# reduction in DISEASE
# ['reduction in ', '']
# DISEASE multiplicity
# ['', ' multiplicity']
# CHEMICAL ( ca )
# ['', ' ( ca )']
# DISEASE and liver
# ['', ' and liver']
# inhibition of DISEASE
# ['inhibition of ', '']
# CHEMICAL generation
# ['', ' generation']
# combination with GENE
# ['combination with ', '']
# major DISEASE
# ['major ', '']
# the GENE inhibitor
# ['the ', ' inhibitor']
# 8 SPECIES
# ['8 SPECIES']
# the active metabolite of CHEMICAL
# ['the active metabolite of ', '']
# CHEMICAL dosage
# ['', ' dosage']
# transporter GENE
# ['transporter ', '']
# mrna in SPECIES
# ['mrna in SPECIES']
# GENE message
# ['', ' message']
# DISEASE level
# ['', ' level']
# the SPECIES uterus
# ['the SPECIES uterus']
# CHEMICAL ( p4 )
# ['', ' ( p4 )']
# CHEMICAL transfer
# ['', ' transfer']
# ovariectomized SPECIES
# ['ovariectomized SPECIES']
# the GENE response
# ['the ', ' response']
# e2 or CHEMICAL
# ['e2 or ', '']
# DISEASE necrosis factor alpha
# ['', ' necrosis factor alpha']
# CHEMICAL action
# ['', ' action']
# GENE current
# ['', ' current']
# the incorporation of CHEMICAL
# ['the incorporation of ', '']
# sensitivity to CHEMICAL
# ['sensitivity to ', '']
# CHEMICAL ion
# ['', ' ion']
# insulin resistance and DISEASE
# ['insulin resistance and ', '']
# hepatic GENE
# ['hepatic ', '']
# experimental DISEASE
# ['experimental ', '']
# CHEMICAL reactive substance
# ['', ' reactive substance']
# CHEMICAL animal
# ['', ' animal']
# hej SPECIES
# ['hej SPECIES']
# protein in SPECIES
# ['protein in SPECIES']
# c SPECIES
# ['c SPECIES']
# CHEMICAL diet
# ['', ' diet']
# repeat CHEMICAL
# ['repeat ', '']
# striatal GENE
# ['striatal ', '']
# SPECIES t
# ['SPECIES t']
# SPECIES and mammal
# ['SPECIES and mammal']
# the growth of SPECIES
# ['the growth of SPECIES']
# CHEMICAL uptake
# ['', ' uptake']
# SPECIES liver mitochondria
# ['SPECIES liver mitochondria']
# type GENE
# ['type ', '']
# the management of DISEASE
# ['the management of ', '']
# the transport of CHEMICAL
# ['the transport of ', '']
# GENE transport
# ['', ' transport']
# pretreatment of SPECIES
# ['pretreatment of SPECIES']
# that treatment with CHEMICAL
# ['that treatment with ', '']
# utero exposure to CHEMICAL
# ['utero exposure to ', '']
# chronic CHEMICAL
# ['chronic ', '']
# adrenal CHEMICAL
# ['adrenal ', '']
# activation of GENE
# ['activation of ', '']
# activation by CHEMICAL
# ['activation by ', '']
# CHEMICAL pretreatment
# ['', ' pretreatment']
# availability of CHEMICAL
# ['availability of ', '']
# the gene GENE
# ['the gene ', '']
# encoding GENE
# ['encoding ', '']
# SPECIES fibroblast cell
# ['SPECIES fibroblast cell']
# CHEMICAL increase
# ['', ' increase']
# contractile response to CHEMICAL
# ['contractile response to ', '']
# CHEMICAL drug
# ['', ' drug']
# the GENE gene promoter
# ['the ', ' gene promoter']
# overexpression of GENE
# ['overexpression of ', '']
# a target of CHEMICAL
# ['a target of ', '']
# a SPECIES model
# ['a SPECIES model']
# fish SPECIES
# ['fish SPECIES']
# CHEMICAL transferase activity
# ['', ' transferase activity']
# animal model of DISEASE
# ['animal model of ', '']
# DISEASE therapy
# ['', ' therapy']
# CHEMICAL on growth
# ['', ' on growth']
# selective DISEASE
# ['selective ', '']
# GENE type
# ['', ' type']
# the nuclear translocation of GENE
# ['the nuclear translocation of ', '']
# translocation of GENE
# ['translocation of ', '']
# the transcription factor GENE
# ['the transcription factor ', '']
# 20 SPECIES
# ['20 SPECIES']
# lung DISEASE
# ['lung ', '']
# expression of GENE in cell
# ['expression of ', ' in cell']
# an antagonist of GENE
# ['an antagonist of ', '']
# alpha ( GENE
# ['alpha ( ', '']
# number of SPECIES
# ['number of SPECIES']
# CHEMICAL x
# ['', ' x']
# SPECIES risk
# ['SPECIES risk']
# the testis of SPECIES
# ['the testis of SPECIES']
# adult male SPECIES
# ['adult male SPECIES']
# CHEMICAL body
# ['', ' body']
# release of GENE
# ['release of ', '']
# recombinant GENE
# ['recombinant ', '']
# CHEMICAL mixture
# ['', ' mixture']
# inhibitory effect of CHEMICAL
# ['inhibitory effect of ', '']
# that CHEMICAL bind
# ['that ', ' bind']
# an important role in DISEASE
# ['an important role in ', '']
# the GENE polymorphism
# ['the ', ' polymorphism']
# DISEASE progression
# ['', ' progression']
# GENE alteration
# ['', ' alteration']
# nuclear GENE
# ['nuclear ', '']
# the mechanism of GENE
# ['the mechanism of ', '']
# interaction between GENE
# ['interaction between ', '']
# hepatic DISEASE
# ['hepatic ', '']
# liver DISEASE
# ['liver ', '']
# CHEMICAL cotransporter
# ['', ' cotransporter']
# GENE correlate
# ['', ' correlate']
# inhibition of SPECIES
# ['inhibition of SPECIES']
# cultured SPECIES cell
# ['cultured SPECIES cell']
# the DISEASE suppressor gene
# ['the ', ' suppressor gene']
# DISEASE pathology
# ['', ' pathology']
# CHEMICAL signal
# ['', ' signal']
# CHEMICAL and insulin
# ['', ' and insulin']
# SPECIES mutant
# ['SPECIES mutant']
# domain of GENE
# ['domain of ', '']
# the CHEMICAL site
# ['the ', ' site']
# CHEMICAL antagonist
# ['', ' antagonist']
# immunotoxic effect of CHEMICAL
# ['immunotoxic effect of ', '']
# 5 microm CHEMICAL
# ['5 microm ', '']
# SPECIES mesangial cell
# ['SPECIES mesangial cell']
# reactive CHEMICAL intermediate
# ['reactive ', ' intermediate']
# GENE accumulation
# ['', ' accumulation']
# GENE protein expression
# ['', ' protein expression']
# stability of GENE
# ['stability of ', '']
# CHEMICAL dehydrogenase activity
# ['', ' dehydrogenase activity']
# endogenous GENE expression
# ['endogenous ', ' expression']
# endogenous GENE
# ['endogenous ', '']
# a severe DISEASE
# ['a severe ', '']
# SPECIES population
# ['SPECIES population']
# CHEMICAL homeostasis
# ['', ' homeostasis']
# effect of CHEMICAL
# ['effect of ', '']
# the endogenous CHEMICAL
# ['the endogenous ', '']
# the activation of CHEMICAL
# ['the activation of ', '']
# GENE knockout
# ['', ' knockout']
# response to GENE
# ['response to ', '']
# the CHEMICAL content
# ['the ', ' content']
# CHEMICAL proliferation
# ['', ' proliferation']
# the course of DISEASE
# ['the course of ', '']
# the formation of DISEASE
# ['the formation of ', '']
# an increase of GENE
# ['an increase of ', '']
# GENE alter
# ['', ' alter']
# GENE therapy
# ['', ' therapy']
# > CHEMICAL
# ['> ', '']
# an CHEMICAL group
# ['an ', ' group']
# SPECIES and control
# ['SPECIES and control']
# concentration of CHEMICAL
# ['concentration of ', '']
# the SPECIES group
# ['the SPECIES group']
# CHEMICAL efflux from cell
# ['', ' efflux from cell']
# SPECIES dermal fibroblast
# ['SPECIES dermal fibroblast']
# the production of DISEASE
# ['the production of ', '']
# CHEMICAL in culture
# ['', ' in culture']
# level of GENE
# ['level of ', '']
# amelioration of DISEASE
# ['amelioration of ', '']
# SPECIES pancreatic islet
# ['SPECIES pancreatic islet']
# l CHEMICAL
# ['l ', '']
# cervical DISEASE
# ['cervical ', '']
# DISEASE type
# ['', ' type']
# three SPECIES
# ['three SPECIES']
# the GENE cdna
# ['the ', ' cdna']
# the cellular response to CHEMICAL
# ['the cellular response to ', '']
# GENE mrna level
# ['', ' mrna level']
# j SPECIES
# ['j SPECIES']
# SPECIES lens
# ['SPECIES lens']
# the CHEMICAL level
# ['the ', ' level']
# an inhibitor of GENE
# ['an inhibitor of ', '']
# CHEMICAL red
# ['', ' red']
# CHEMICAL degradation
# ['', ' degradation']
# the distribution of CHEMICAL
# ['the distribution of ', '']
# GENE expression in
# ['', ' expression in']
# the SPECIES cell line
# ['the SPECIES cell line']
# GENE induction
# ['', ' induction']
# production in SPECIES
# ['production in SPECIES']
# SPECIES being
# ['SPECIES being']
# the CHEMICAL family
# ['the ', ' family']
# liver GENE
# ['liver ', '']
# GENE gene
# ['', ' gene']
# mrna level for GENE
# ['mrna level for ', '']
# the serum concentration of CHEMICAL
# ['the serum concentration of ', '']
# synthesis of CHEMICAL
# ['synthesis of ', '']
# neither CHEMICAL
# ['neither ', '']
# CHEMICAL bw
# ['', ' bw']
# SPECIES kidney
# ['SPECIES kidney']
# SPECIES embryonic kidney
# ['SPECIES embryonic kidney']
# GENE form
# ['', ' form']
# ( GENE inhibitor )
# ['( ', ' inhibitor )']
# intracellular accumulation of CHEMICAL
# ['intracellular accumulation of ', '']
# kidney GENE
# ['kidney ', '']
# the growth of DISEASE
# ['the growth of ', '']
# hepatocyte DISEASE
# ['hepatocyte ', '']
# kidney of SPECIES
# ['kidney of SPECIES']
# the ratio of GENE
# ['the ratio of ', '']
# ( GENE ) protein level
# ['( ', ' ) protein level']
# the uterus of SPECIES
# ['the uterus of SPECIES']
# human GENE ( hsa )
# ['human ', ' ( hsa )']
# CHEMICAL or derivative
# ['', ' or derivative']
# the DISEASE phenotype
# ['the ', ' phenotype']
# two DISEASE
# ['two ', '']
# mutation of GENE
# ['mutation of ', '']
# CHEMICAL mutation
# ['', ' mutation']
# a low dose of CHEMICAL
# ['a low dose of ', '']
# GENE signaling pathway
# ['', ' signaling pathway']
# enhancement of CHEMICAL
# ['enhancement of ', '']
# GENE pathway
# ['', ' pathway']
# GENE signaling
# ['', ' signaling']
# CHEMICAL receptor subtype
# ['', ' receptor subtype']
# muscarinic CHEMICAL
# ['muscarinic ', '']
# CHEMICAL ( op )
# ['', ' ( op )']
# the early stage of DISEASE
# ['the early stage of ', '']
# CHEMICAL exposure
# ['', ' exposure']
# GENE methylation
# ['', ' methylation']
# intimal DISEASE
# ['intimal ', '']
# CHEMICAL conductance
# ['', ' conductance']
# CHEMICAL phosphorylation
# ['', ' phosphorylation']
# DISEASE outcome
# ['', ' outcome']
# SPECIES brain
# ['SPECIES brain']
# various CHEMICAL
# ['various ', '']
# both DISEASE cell line
# ['both ', ' cell line']
# both DISEASE cell
# ['both ', ' cell']
# CHEMICAL treatment ,
# ['', ' treatment ,']
# basal CHEMICAL
# ['basal ', '']
# DISEASE mutation
# ['', ' mutation']
# DISEASE susceptibility
# ['', ' susceptibility']
# resistance of SPECIES
# ['resistance of SPECIES']
# lew SPECIES
# ['lew SPECIES']
# GENE inhibitor
# ['', ' inhibitor']
# bn SPECIES
# ['bn SPECIES']
# the CHEMICAL production
# ['the ', ' production']
# the intracellular CHEMICAL content
# ['the intracellular ', ' content']
# intracellular CHEMICAL content
# ['intracellular ', ' content']
# primary SPECIES
# ['primary SPECIES']
# GENE messenger
# ['', ' messenger']
# the absence of DISEASE
# ['the absence of ', '']
# inhibitor CHEMICAL
# ['inhibitor ', '']
# repression of GENE
# ['repression of ', '']
# GENE and b
# ['', ' and b']
# GENE gene transcription
# ['', ' gene transcription']
# CHEMICAL formulation
# ['', ' formulation']
# CHEMICAL preparation
# ['', ' preparation']
# a role for GENE
# ['a role for ', '']
# combination of GENE
# ['combination of ', '']
# GENE result
# ['', ' result']
# CHEMICAL hydroxylase mrna
# ['', ' hydroxylase mrna']
# intrathecal CHEMICAL
# ['intrathecal ', '']
# neuronal CHEMICAL
# ['neuronal ', '']
# the etiology of DISEASE
# ['the etiology of ', '']
# synthesis of GENE
# ['synthesis of ', '']
# DISEASE action
# ['', ' action']
# the treatment with CHEMICAL
# ['the treatment with ', '']
# plasma DISEASE
# ['plasma ', '']
# the CHEMICAL metabolite
# ['the ', ' metabolite']
# CHEMICAL receptor
# ['', ' receptor']
# agent CHEMICAL
# ['agent ', '']
# the effect of CHEMICAL on proliferation
# ['the effect of ', ' on proliferation']
# generation of CHEMICAL
# ['generation of ', '']
# GENE agonist
# ['', ' agonist']
# CHEMICAL overload
# ['', ' overload']
# the GENE genotype
# ['the ', ' genotype']
# a single injection of CHEMICAL
# ['a single injection of ', '']
# various DISEASE cell
# ['various ', ' cell']
# CHEMICAL redox
# ['', ' redox']
# CHEMICAL methylation
# ['', ' methylation']
# an increase in GENE
# ['an increase in ', '']
# the presence of CHEMICAL
# ['the presence of ', '']
# the CHEMICAL synthesis pathway
# ['the ', ' synthesis pathway']
# a variety of DISEASE
# ['a variety of ', '']
# DISEASE cell type
# ['', ' cell type']
# SPECIES b
# ['SPECIES b']
# the inhibition of DISEASE
# ['the inhibition of ', '']
# the initiation of DISEASE
# ['the initiation of ', '']
# GENE ) gene
# ['', ' ) gene']
# CHEMICAL product
# ['', ' product']
# expression of SPECIES
# ['expression of SPECIES']
# injection of CHEMICAL
# ['injection of ', '']
# mutant SPECIES
# ['mutant SPECIES']
# preincubation with CHEMICAL
# ['preincubation with ', '']
# the mrna level of GENE
# ['the mrna level of ', '']
# SPECIES cell line
# ['SPECIES cell line']
# GENE in cell
# ['', ' in cell']
# lead CHEMICAL
# ['lead ', '']
# the GENE protein
# ['the ', ' protein']
# sex CHEMICAL
# ['sex ', '']
# DISEASE challenge
# ['', ' challenge']
# vitro DISEASE
# ['vitro ', '']
# CHEMICAL induce apoptosis
# ['', ' induce apoptosis']
# CHEMICAL donor
# ['', ' donor']
# CHEMICAL transport
# ['', ' transport']
# effect of CHEMICAL on expression
# ['effect of ', ' on expression']
# specific CHEMICAL
# ['specific ', '']
# CHEMICAL phosphatase
# ['', ' phosphatase']
# contrast to GENE
# ['contrast to ', '']
# lung CHEMICAL
# ['lung ', '']
# lung GENE
# ['lung ', '']
# liver CHEMICAL level
# ['liver ', ' level']
# a combination of CHEMICAL
# ['a combination of ', '']
# the SPECIES liver
# ['the SPECIES liver']
# ligand activation of GENE
# ['ligand activation of ', '']
# immunoreactive GENE
# ['immunoreactive ', '']
# 11 SPECIES
# ['11 SPECIES']
# untreated SPECIES
# ['untreated SPECIES']
# identification of GENE
# ['identification of ', '']
# the identification of GENE
# ['the identification of ', '']
# implication for DISEASE
# ['implication for ', '']
# therapy in DISEASE
# ['therapy in ', '']
# advanced DISEASE
# ['advanced ', '']
# CHEMICAL inhibitory effect
# ['', ' inhibitory effect']
# a single intraperitoneal injection of CHEMICAL
# ['a single intraperitoneal injection of ', '']
# antagonist CHEMICAL
# ['antagonist ', '']
# the efficacy of CHEMICAL
# ['the efficacy of ', '']
# seven DISEASE
# ['seven ', '']
# secondary DISEASE
# ['secondary ', '']
# more severe DISEASE
# ['more severe ', '']
# molecular CHEMICAL
# ['molecular ', '']
# GENE gene mutation
# ['', ' gene mutation']
# grade DISEASE
# ['grade ', '']
# the molecular mechanism of DISEASE
# ['the molecular mechanism of ', '']
# exposure to GENE
# ['exposure to ', '']
# 1 microm CHEMICAL
# ['1 microm ', '']
# GENE status
# ['', ' status']
# sensitivity of DISEASE
# ['sensitivity of ', '']
# SPECIES blood
# ['SPECIES blood']
# nine SPECIES
# ['nine SPECIES']
# wt GENE
# ['wt ', '']
# the GENE subtype
# ['the ', ' subtype']
# the SPECIES diet
# ['the SPECIES diet']
# DISEASE etiology
# ['', ' etiology']
# human DISEASE
# ['human ', '']
# SPECIES liver cell
# ['SPECIES liver cell']
# antiestrogen CHEMICAL
# ['antiestrogen ', '']
# SPECIES epithelial cell
# ['SPECIES epithelial cell']
# hydroxylation of CHEMICAL
# ['hydroxylation of ', '']
# CHEMICAL methyltransferase
# ['', ' methyltransferase']
# acute CHEMICAL intoxication
# ['acute ', ' intoxication']
# intestinal DISEASE
# ['intestinal ', '']
# the biliary excretion of CHEMICAL
# ['the biliary excretion of ', '']
# permanent DISEASE
# ['permanent ', '']
# CHEMICAL p
# ['', ' p']
# CHEMICAL secretion
# ['', ' secretion']
# GENE hydrolase
# ['', ' hydrolase']
# CHEMICAL gene
# ['', ' gene']
# SPECIES health
# ['SPECIES health']
# many DISEASE
# ['many ', '']
# the secretion of CHEMICAL
# ['the secretion of ', '']
# the GENE isoform
# ['the ', ' isoform']
# the influence of CHEMICAL
# ['the influence of ', '']
# CHEMICAL d3
# ['', ' d3']
# SPECIES ovary cell
# ['SPECIES ovary cell']
# SPECIES peritoneal macrophage
# ['SPECIES peritoneal macrophage']
# ligand CHEMICAL
# ['ligand ', '']
# withdrawal of CHEMICAL
# ['withdrawal of ', '']
# experimental model of DISEASE
# ['experimental model of ', '']
# SPECIES peripheral blood monocyte
# ['SPECIES peripheral blood monocyte']
# the GENE gene expression
# ['the ', ' gene expression']
# pretreatment of CHEMICAL
# ['pretreatment of ', '']
# the GENE receptor
# ['the ', ' receptor']
# reactive CHEMICAL metabolite
# ['reactive ', ' metabolite']
# SPECIES p450
# ['SPECIES p450']
# the CHEMICAL response
# ['the ', ' response']
# combination of CHEMICAL
# ['combination of ', '']
# chronic exposure of SPECIES
# ['chronic exposure of SPECIES']
# the ability of CHEMICAL
# ['the ability of ', '']
# CHEMICAL hydrolysis
# ['', ' hydrolysis']
# breast and DISEASE
# ['breast and ', '']
# the CHEMICAL insecticide
# ['the ', ' insecticide']
# the GENE allele
# ['the ', ' allele']
# resistance to DISEASE
# ['resistance to ', '']
# the plasma of SPECIES
# ['the plasma of SPECIES']
# direct DISEASE
# ['direct ', '']
# sencar SPECIES
# ['sencar SPECIES']
# a subset of DISEASE
# ['a subset of ', '']
# a DISEASE promoter
# ['a ', ' promoter']
# CHEMICAL , expression
# ['', ' , expression']
# loss of GENE
# ['loss of ', '']
# functional GENE
# ['functional ', '']
# GENE protein expression and
# ['', ' protein expression and']
# DISEASE promotion
# ['', ' promotion']
# CHEMICAL ligand
# ['', ' ligand']
# upregulation of GENE
# ['upregulation of ', '']
# CHEMICAL daily
# ['', ' daily']
# high level of CHEMICAL
# ['high level of ', '']
# ( GENE ) inhibitor
# ['( ', ' ) inhibitor']
# an intraperitoneal injection of CHEMICAL
# ['an intraperitoneal injection of ', '']
# SPECIES ec
# ['SPECIES ec']
# chrysotile DISEASE
# ['chrysotile ', '']
# DISEASE and/or
# ['', ' and/or']
# CHEMICAL synthase
# ['', ' synthase']
# CHEMICAL neurone
# ['', ' neurone']
# fas and GENE
# ['fas and ', '']
# some DISEASE cell
# ['some ', ' cell']
# the GENE system
# ['the ', ' system']
# developmental DISEASE
# ['developmental ', '']
# derivative CHEMICAL
# ['derivative ', '']
# the SPECIES heart
# ['the SPECIES heart']
# CHEMICAL intermediate
# ['', ' intermediate']
# inflammatory DISEASE
# ['inflammatory ', '']
# active metabolite of CHEMICAL
# ['active metabolite of ', '']
# growth inhibition by CHEMICAL
# ['growth inhibition by ', '']
# CHEMICAL elevation
# ['', ' elevation']
# isolated SPECIES heart
# ['isolated SPECIES heart']
# determination of CHEMICAL
# ['determination of ', '']
# the intracellular CHEMICAL level
# ['the intracellular ', ' level']
# cytochrome GENE
# ['cytochrome ', '']
# a ligand for GENE
# ['a ligand for ', '']
# many SPECIES
# ['many SPECIES']
# the agonist CHEMICAL
# ['the agonist ', '']
# hepatocyte of SPECIES
# ['hepatocyte of SPECIES']
# SPECIES assay
# ['SPECIES assay']
# SPECIES testis
# ['SPECIES testis']
# analysis of GENE
# ['analysis of ', '']
# DISEASE 2
# ['', ' 2']
# GENE allele
# ['', ' allele']
# application of CHEMICAL
# ['application of ', '']
# the number of DISEASE
# ['the number of ', '']
# conscious SPECIES
# ['conscious SPECIES']
# 10 mg CHEMICAL
# ['10 mg ', '']
# the CHEMICAL diet
# ['the ', ' diet']
# CHEMICAL carboxykinase
# ['', ' carboxykinase']
# either vehicle or CHEMICAL
# ['either vehicle or ', '']
# vitro exposure to CHEMICAL
# ['vitro exposure to ', '']
# a novel CHEMICAL derivative
# ['a novel ', ' derivative']
# GENE and protein
# ['', ' and protein']
# muscarinic CHEMICAL receptor
# ['muscarinic ', ' receptor']
# vivo effect of CHEMICAL
# ['vivo effect of ', '']
# blockade with CHEMICAL
# ['blockade with ', '']
# degree of DISEASE
# ['degree of ', '']
# DISEASE resistance
# ['', ' resistance']
# DISEASE expression
# ['', ' expression']
# GENE expression in cell
# ['', ' expression in cell']
# simultaneous treatment with CHEMICAL
# ['simultaneous treatment with ', '']
# CHEMICAL genotoxicity
# ['', ' genotoxicity']
# immune response in SPECIES
# ['immune response in SPECIES']
# susceptible SPECIES
# ['susceptible SPECIES']
# the protective effect of CHEMICAL
# ['the protective effect of ', '']
# GENE infusion
# ['', ' infusion']
# serum CHEMICAL concentration
# ['serum ', ' concentration']
# acth and CHEMICAL
# ['acth and ', '']
# CHEMICAL replacement therapy
# ['', ' replacement therapy']
# gene in DISEASE
# ['gene in ', '']
# SPECIES monocytic cell line
# ['SPECIES monocytic cell line']
# enhancement of GENE
# ['enhancement of ', '']
# multiple DISEASE
# ['multiple ', '']
# DISEASE virus
# ['', ' virus']
# response of DISEASE
# ['response of ', '']
# a SPECIES cell line
# ['a SPECIES cell line']
# the apoptotic effect of CHEMICAL
# ['the apoptotic effect of ', '']
# CHEMICAL receptor antagonist
# ['', ' receptor antagonist']
# striatal CHEMICAL
# ['striatal ', '']
# the CHEMICAL donor
# ['the ', ' donor']
# SPECIES gene
# ['SPECIES gene']
# neonatal exposure to CHEMICAL
# ['neonatal exposure to ', '']
# the loss of CHEMICAL
# ['the loss of ', '']
# uterine DISEASE
# ['uterine ', '']
# CHEMICAL suppress
# ['', ' suppress']
# the generation of DISEASE
# ['the generation of ', '']
# DISEASE generation
# ['', ' generation']
# significant DISEASE
# ['significant ', '']
# CHEMICAL hydroxylase
# ['', ' hydroxylase']
# most abundant CHEMICAL
# ['most abundant ', '']
# CHEMICAL expression
# ['', ' expression']
# the deduced CHEMICAL sequence
# ['the deduced ', ' sequence']
# h. CHEMICAL
# ['h. ', '']
# CHEMICAL current
# ['', ' current']
# normal CHEMICAL
# ['normal ', '']
# GENE enzyme activity
# ['', ' enzyme activity']
# CHEMICAL treatment of cell
# ['', ' treatment of cell']
# CHEMICAL or placebo
# ['', ' or placebo']
# CHEMICAL content
# ['', ' content']
# several DISEASE
# ['several ', '']
# SPECIES mononuclear cell
# ['SPECIES mononuclear cell']
# ml CHEMICAL
# ['ml ', '']
# DISEASE protein and
# ['', ' protein and']
# apoptosis in DISEASE
# ['apoptosis in ', '']
# CHEMICAL oxidase activity
# ['', ' oxidase activity']
# GENE transgene
# ['', ' transgene']
# SPECIES plasma
# ['SPECIES plasma']
# the high concentration of CHEMICAL
# ['the high concentration of ', '']
# suppression of DISEASE
# ['suppression of ', '']
# model of DISEASE
# ['model of ', '']
# production and CHEMICAL
# ['production and ', '']
# the SPECIES lung
# ['the SPECIES lung']
# renal DISEASE
# ['renal ', '']
# a role of GENE
# ['a role of ', '']
# mutation in DISEASE
# ['mutation in ', '']
# three DISEASE cell line
# ['three ', ' cell line']
# GENE enzymatic activity
# ['', ' enzymatic activity']
# a high dose of CHEMICAL
# ['a high dose of ', '']
# GENE complex
# ['', ' complex']
# japanese SPECIES
# ['japanese SPECIES']
# eight SPECIES
# ['eight SPECIES']
# chronic treatment with CHEMICAL
# ['chronic treatment with ', '']
# normal GENE
# ['normal ', '']
# DISEASE death
# ['', ' death']
# 13 SPECIES
# ['13 SPECIES']
# a synthetic CHEMICAL
# ['a synthetic ', '']
# CHEMICAL bond
# ['', ' bond']
# introduction of GENE
# ['introduction of ', '']
# reduced CHEMICAL
# ['reduced ', '']
# the intracellular concentration of CHEMICAL
# ['the intracellular concentration of ', '']
# the level of DISEASE
# ['the level of ', '']
# serum GENE level
# ['serum ', ' level']
# the frequency of DISEASE
# ['the frequency of ', '']
# GENE deficient
# ['', ' deficient']
# the DISEASE area
# ['the ', ' area']
# a direct effect of CHEMICAL
# ['a direct effect of ', '']
# the function of GENE
# ['the function of ', '']
# CHEMICAL dismutase ( sod )
# ['', ' dismutase ( sod )']
# CHEMICAL peroxidase ( gpx )
# ['', ' peroxidase ( gpx )']
# the SPECIES testis
# ['the SPECIES testis']
# CHEMICAL substrate
# ['', ' substrate']
# the GENE synthase
# ['the ', ' synthase']
# a history of DISEASE
# ['a history of ', '']
# acute CHEMICAL exposure
# ['acute ', ' exposure']
# environmental CHEMICAL
# ['environmental ', '']
# CHEMICAL >
# ['', ' >']
# the DISEASE protein
# ['the ', ' protein']
# ectopic expression of GENE
# ['ectopic expression of ', '']
# the action of CHEMICAL
# ['the action of ', '']
# b16 DISEASE
# ['b16 ', '']
# the CHEMICAL cycle
# ['the ', ' cycle']
# 16 SPECIES
# ['16 SPECIES']
# different SPECIES
# ['different SPECIES']
# allele of GENE
# ['allele of ', '']
# c57bl/6j SPECIES
# ['c57bl/6j SPECIES']
# DISEASE suppressor gene
# ['', ' suppressor gene']
# an analog of CHEMICAL
# ['an analog of ', '']
# GENE cleavage
# ['', ' cleavage']
# the control SPECIES
# ['the control SPECIES']
# protein , CHEMICAL
# ['protein , ', '']
# the blood of SPECIES
# ['the blood of SPECIES']
# DISEASE abuse
# ['', ' abuse']
# and/or DISEASE
# ['and/or ', '']
# CHEMICAL sensor
# ['', ' sensor']
# an CHEMICAL chelator
# ['an ', ' chelator']
# apoptosis of DISEASE
# ['apoptosis of ', '']
# a DISEASE cell line ,
# ['a ', ' cell line ,']
# the overexpression of GENE
# ['the overexpression of ', '']
# biliary CHEMICAL secretion
# ['biliary ', ' secretion']
# CHEMICAL immunotoxicity
# ['', ' immunotoxicity']
# three DISEASE
# ['three ', '']
# SPECIES result
# ['SPECIES result']
# CHEMICAL formation
# ['', ' formation']
# the cardioprotective effect of CHEMICAL
# ['the cardioprotective effect of ', '']
# the effect of CHEMICAL on apoptosis
# ['the effect of ', ' on apoptosis']
# GENE degradation
# ['', ' degradation']
# GENE phosphorylation
# ['', ' phosphorylation']
# incubation of CHEMICAL
# ['incubation of ', '']
# CHEMICAL form
# ['', ' form']
# the induction of GENE
# ['the induction of ', '']
# CHEMICAL agonist
# ['', ' agonist']
# GENE variant
# ['', ' variant']
# CHEMICAL agent
# ['', ' agent']
# CHEMICAL affinity
# ['', ' affinity']
# zucker SPECIES
# ['zucker SPECIES']
# action of GENE
# ['action of ', '']
# absence of GENE
# ['absence of ', '']
# the GENE subunit
# ['the ', ' subunit']
# reversible DISEASE
# ['reversible ', '']
# CHEMICAL control
# ['', ' control']
# a natural CHEMICAL
# ['a natural ', '']
# CHEMICAL substance
# ['', ' substance']
# CHEMICAL injury
# ['', ' injury']
# decrease of CHEMICAL
# ['decrease of ', '']
# the increase of CHEMICAL
# ['the increase of ', '']
# treatment with CHEMICAL
# ['treatment with ', '']
# culture of SPECIES
# ['culture of SPECIES']
# swiss SPECIES
# ['swiss SPECIES']
# transport of CHEMICAL
# ['transport of ', '']
# reversal of DISEASE
# ['reversal of ', '']
# GENE immunoreactivity
# ['', ' immunoreactivity']
# GENE gene in cell
# ['', ' gene in cell']
# SPECIES keratinocyte
# ['SPECIES keratinocyte']
# transactivation of GENE
# ['transactivation of ', '']
# receptor GENE
# ['receptor ', '']
# CHEMICAL and cytokine
# ['', ' and cytokine']
# GENE map
# ['', ' map']
# phosphorylation of GENE
# ['phosphorylation of ', '']
# CHEMICAL kinase receptor
# ['', ' kinase receptor']
# the kinase inhibitor CHEMICAL
# ['the kinase inhibitor ', '']
# SPECIES epidermal melanocyte
# ['SPECIES epidermal melanocyte']
# CHEMICAL alter
# ['', ' alter']
# CHEMICAL deposition
# ['', ' deposition']
# SPECIES t cell
# ['SPECIES t cell']
# the GENE target gene
# ['the ', ' target gene']
# SPECIES body
# ['SPECIES body']
# DISEASE cell death
# ['', ' cell death']
# DISEASE and associate
# ['', ' and associate']
# the expression of GENE )
# ['the expression of ', ' )']
# DISEASE and change
# ['', ' and change']
# CHEMICAL sequencing
# ['', ' sequencing']
# DISEASE factor
# ['', ' factor']
# SPECIES 2
# ['SPECIES 2']
# CHEMICAL reactive substance ( tbars )
# ['', ' reactive substance ( tbars )']
# CHEMICAL ) depletion
# ['', ' ) depletion']
# addition to GENE
# ['addition to ', '']
# association with DISEASE
# ['association with ', '']
# CHEMICAL load
# ['', ' load']
# DISEASE severity
# ['', ' severity']
# the site of DISEASE
# ['the site of ', '']
# GENE receptor alpha
# ['', ' receptor alpha']
# the CHEMICAL hormone
# ['the ', ' hormone']
# CHEMICAL in combination
# ['', ' in combination']
# the GENE signaling pathway
# ['the ', ' signaling pathway']
# alpha ( GENE )
# ['alpha ( ', ' )']
# CHEMICAL on expression
# ['', ' on expression']
# the female SPECIES
# ['the female SPECIES']
# CHEMICAL mrna
# ['', ' mrna']
# GENE synthesis
# ['', ' synthesis']
# CHEMICAL ( 0.1 ,
# ['', ' ( 0.1 ,']
# receptor antagonist CHEMICAL
# ['receptor antagonist ', '']
# receptor agonist CHEMICAL
# ['receptor agonist ', '']
# SPECIES airway epithelial cell
# ['SPECIES airway epithelial cell']
# fatal DISEASE
# ['fatal ', '']
# GENE , protein
# ['', ' , protein']
# therapy with CHEMICAL
# ['therapy with ', '']
# DISEASE infection
# ['', ' infection']
# CHEMICAL specie
# ['', ' specie']
# protein GENE
# ['protein ', '']
# uptake of CHEMICAL
# ['uptake of ', '']
# SPECIES chromosome
# ['SPECIES chromosome']
# m CHEMICAL
# ['m ', '']
# CHEMICAL stimulate
# ['', ' stimulate']
# the direct effect of CHEMICAL
# ['the direct effect of ', '']
# the case of CHEMICAL
# ['the case of ', '']
# CHEMICAL complex
# ['', ' complex']
# DISEASE in animal
# ['', ' in animal']
# CHEMICAL and lead
# ['', ' and lead']
# CHEMICAL analogue ,
# ['', ' analogue ,']
# CHEMICAL bind
# ['', ' bind']
# acute CHEMICAL
# ['acute ', '']
# CHEMICAL and expression
# ['', ' and expression']
# activity of GENE
# ['activity of ', '']
# knockout SPECIES
# ['knockout SPECIES']
# signaling in DISEASE
# ['signaling in ', '']
# the expression of DISEASE
# ['the expression of ', '']
# CHEMICAL mustard ( sm )
# ['', ' mustard ( sm )']
# CHEMICAL incorporation into dna
# ['', ' incorporation into dna']
# CHEMICAL treatment
# ['', ' treatment']
# DISEASE incidence
# ['', ' incidence']
# a specific inhibitor of GENE
# ['a specific inhibitor of ', '']
# interaction between CHEMICAL
# ['interaction between ', '']
# SPECIES mammary epithelial cell
# ['SPECIES mammary epithelial cell']
# oxidation of CHEMICAL
# ['oxidation of ', '']
# direct GENE inhibitor
# ['direct ', ' inhibitor']
# CHEMICAL excess
# ['', ' excess']
# neuronal nicotinic CHEMICAL receptor
# ['neuronal nicotinic ', ' receptor']
# mutant GENE
# ['mutant ', '']
# protective effect of CHEMICAL
# ['protective effect of ', '']
# a significant increase in CHEMICAL
# ['a significant increase in ', '']
# total CHEMICAL content
# ['total ', ' content']
# the relationship between DISEASE
# ['the relationship between ', '']
# no effect of CHEMICAL
# ['no effect of ', '']
# the potential role of CHEMICAL
# ['the potential role of ', '']
# vitro DISEASE model
# ['vitro ', ' model']
# GENE mapk
# ['', ' mapk']
# dissociation of GENE
# ['dissociation of ', '']
# CHEMICAL carcinogenicity
# ['', ' carcinogenicity']
# the generation of CHEMICAL
# ['the generation of ', '']
# SPECIES embryonic kidney cell
# ['SPECIES embryonic kidney cell']
# alter GENE
# ['alter ', '']
# expression in DISEASE
# ['expression in ', '']
# GENE protein level
# ['', ' protein level']
# treatment with CHEMICAL alone
# ['treatment with ', ' alone']
# differential regulation of GENE
# ['differential regulation of ', '']
# the pathology of DISEASE
# ['the pathology of ', '']
# degradation of GENE
# ['degradation of ', '']
# m. CHEMICAL
# ['m. ', '']
# GENE and dna
# ['', ' and dna']
# the GENE complex
# ['the ', ' complex']
# the GENE signaling
# ['the ', ' signaling']
# treatment of CHEMICAL
# ['treatment of ', '']
# culture with CHEMICAL
# ['culture with ', '']
# apoptotic DISEASE
# ['apoptotic ', '']
# SPECIES epidermis
# ['SPECIES epidermis']
# the expression of GENE
# ['the expression of ', '']
# the risk for DISEASE
# ['the risk for ', '']
# oxidative stress and DISEASE
# ['oxidative stress and ', '']
# DISEASE addiction
# ['', ' addiction']
# the pathophysiology of DISEASE
# ['the pathophysiology of ', '']
# CHEMICAL at level
# ['', ' at level']
# conversion of CHEMICAL
# ['conversion of ', '']
# vascular DISEASE
# ['vascular ', '']
# transfection with GENE
# ['transfection with ', '']
# transfection of GENE
# ['transfection of ', '']
# accumulation of DISEASE
# ['accumulation of ', '']
# CHEMICAL d
# ['', ' d']
# DISEASE tissue
# ['', ' tissue']
# protein level of GENE
# ['protein level of ', '']
# GENE gene promoter
# ['', ' gene promoter']
# SPECIES whole blood
# ['SPECIES whole blood']
# antiproliferative effect of CHEMICAL
# ['antiproliferative effect of ', '']
# GENE receptor expression
# ['', ' receptor expression']
# CHEMICAL chelator
# ['', ' chelator']
# SPECIES cytochrome
# ['SPECIES cytochrome']
# immunodeficient SPECIES
# ['immunodeficient SPECIES']
# SPECIES dna
# ['SPECIES dna']
# activity in SPECIES
# ['activity in SPECIES']
# the molecular mechanism of CHEMICAL
# ['the molecular mechanism of ', '']
# CHEMICAL on proliferation
# ['', ' on proliferation']
# GENE upregulation
# ['', ' upregulation']
# the kidney of SPECIES
# ['the kidney of SPECIES']
# rodent DISEASE
# ['rodent ', '']
# ppm CHEMICAL
# ['ppm ', '']
# apoptosis in SPECIES
# ['apoptosis in SPECIES']
# DISEASE and apoptosis
# ['', ' and apoptosis']
# DISEASE liver
# ['', ' liver']
# the prevention and treatment of DISEASE
# ['the prevention and treatment of ', '']
# DISEASE xenograft
# ['', ' xenograft']
# CHEMICAL exert
# ['', ' exert']
# cellular CHEMICAL homeostasis
# ['cellular ', ' homeostasis']
# SPECIES granulosa cell
# ['SPECIES granulosa cell']
# GENE promoter activity
# ['', ' promoter activity']
# microsomal CHEMICAL hydrolase
# ['microsomal ', ' hydrolase']
# l of CHEMICAL
# ['l of ', '']
# the majority of SPECIES
# ['the majority of SPECIES']
# these DISEASE cell
# ['these ', ' cell']
# the modulatory effect of CHEMICAL
# ['the modulatory effect of ', '']
# CHEMICAL exposure in
# ['', ' exposure in']
# cellular CHEMICAL
# ['cellular ', '']
# SPECIES lung fibroblast
# ['SPECIES lung fibroblast']
# the CHEMICAL biosynthetic pathway
# ['the ', ' biosynthetic pathway']
# lack of GENE
# ['lack of ', '']
# CHEMICAL neurotransmission
# ['', ' neurotransmission']
# focal DISEASE
# ['focal ', '']
# progression of DISEASE
# ['progression of ', '']
# a therapeutic agent for DISEASE
# ['a therapeutic agent for ', '']
# GENE product
# ['', ' product']
# the DISEASE model
# ['the ', ' model']
# CHEMICAL m
# ['', ' m']
# CHEMICAL ( ra )
# ['', ' ( ra )']
# DISEASE blast
# ['', ' blast']
# apoptosis of SPECIES
# ['apoptosis of SPECIES']
# the biological activity of CHEMICAL
# ['the biological activity of ', '']
# a protective effect against DISEASE
# ['a protective effect against ', '']
# four DISEASE
# ['four ', '']
# combination with CHEMICAL
# ['combination with ', '']
# inorganic CHEMICAL
# ['inorganic ', '']
# cdk inhibitor GENE
# ['cdk inhibitor ', '']
# CHEMICAL arrest
# ['', ' arrest']
# GENE protein degradation
# ['', ' protein degradation']
# CHEMICAL chelation
# ['', ' chelation']
# CHEMICAL conjugation
# ['', ' conjugation']
# exposure of CHEMICAL
# ['exposure of ', '']
# an GENE inhibitor
# ['an ', ' inhibitor']
# GENE , and protein
# ['', ' , and protein']
# DISEASE individual
# ['', ' individual']
# outcome in SPECIES
# ['outcome in SPECIES']
# SPECIES system
# ['SPECIES system']
# the GENE pathway
# ['the ', ' pathway']
# one CHEMICAL
# ['one ', '']
# arthritic SPECIES
# ['arthritic SPECIES']
# SPECIES mammary gland
# ['SPECIES mammary gland']
# apoptosis by CHEMICAL
# ['apoptosis by ', '']
# elevated expression of GENE
# ['elevated expression of ', '']
# GENE null
# ['', ' null']
# SPECIES extract
# ['SPECIES extract']
# DISEASE and expression
# ['', ' and expression']
# gastric DISEASE
# ['gastric ', '']
# SPECIES vascular endothelial cell
# ['SPECIES vascular endothelial cell']
# variation in GENE
# ['variation in ', '']
# the transfer of CHEMICAL
# ['the transfer of ', '']
# GENE association
# ['', ' association']
# primary SPECIES hepatocyte
# ['primary SPECIES hepatocyte']
# growth of DISEASE
# ['growth of ', '']
# GENE immune response
# ['', ' immune response']
# oral DISEASE
# ['oral ', '']
# CHEMICAL synthase ( enos
# ['', ' synthase ( enos']
# endothelial CHEMICAL
# ['endothelial ', '']
# CHEMICAL level in serum
# ['', ' level in serum']
# elevation in CHEMICAL
# ['elevation in ', '']
# ( DISEASE ) cell line
# ['( ', ' ) cell line']
# the GENE antagonist
# ['the ', ' antagonist']
# CHEMICAL block
# ['', ' block']
# the degradation of GENE
# ['the degradation of ', '']
# CHEMICAL administration
# ['', ' administration']
# the activity of CHEMICAL
# ['the activity of ', '']
# DISEASE mortality
# ['', ' mortality']
# the cytotoxic effect of CHEMICAL
# ['the cytotoxic effect of ', '']
# SPECIES and experimental
# ['SPECIES and experimental']
# GENE dephosphorylation
# ['', ' dephosphorylation']
# the increase in CHEMICAL
# ['the increase in ', '']
# dopaminergic DISEASE
# ['dopaminergic ', '']
# CHEMICAL reductase activity
# ['', ' reductase activity']
# the early phase of DISEASE
# ['the early phase of ', '']
# DISEASE activation
# ['', ' activation']
# activation of DISEASE
# ['activation of ', '']
# DISEASE pathway
# ['', ' pathway']
# idiopathic DISEASE
# ['idiopathic ', '']
# CHEMICAL sod
# ['', ' sod']
# CHEMICAL initiate
# ['', ' initiate']
# CHEMICAL protein
# ['', ' protein']
# use in SPECIES
# ['use in SPECIES']
# GENE synthase
# ['', ' synthase']
# CHEMICAL in cell
# ['', ' in cell']
# the interaction between GENE
# ['the interaction between ', '']
# DISEASE differentiation
# ['', ' differentiation']
# intracellular CHEMICAL mobilization
# ['intracellular ', ' mobilization']
# risk for DISEASE
# ['risk for ', '']
# conclusion : CHEMICAL
# ['conclusion : ', '']
# the CHEMICAL test
# ['the ', ' test']
# SPECIES endothelial cell
# ['SPECIES endothelial cell']
# CHEMICAL ( pe
# ['', ' ( pe']
# an GENE antagonist
# ['an ', ' antagonist']
# perinatal exposure to CHEMICAL
# ['perinatal exposure to ', '']
# CHEMICAL ( 0 ,
# ['', ' ( 0 ,']
# serum level of CHEMICAL
# ['serum level of ', '']
# effect on DISEASE
# ['effect on ', '']
# CHEMICAL aminotransferase
# ['', ' aminotransferase']
# that induction of GENE
# ['that induction of ', '']
# change in CHEMICAL
# ['change in ', '']
# active CHEMICAL
# ['active ', '']
# an animal model of DISEASE
# ['an animal model of ', '']
# CHEMICAL cell
# ['', ' cell']
# CHEMICAL exchange
# ['', ' exchange']
# cytokine and GENE
# ['cytokine and ', '']
# GENE deficiency
# ['', ' deficiency']
# level of CHEMICAL
# ['level of ', '']
# progressive DISEASE ,
# ['progressive ', ' ,']
# spontaneous DISEASE
# ['spontaneous ', '']
# CHEMICAL in macrophage
# ['', ' in macrophage']
# chemical CHEMICAL
# ['chemical ', '']
# relation to CHEMICAL
# ['relation to ', '']
# CHEMICAL prevent
# ['', ' prevent']
# a decrease in CHEMICAL
# ['a decrease in ', '']
# molecule GENE
# ['molecule ', '']
# the oral administration of CHEMICAL
# ['the oral administration of ', '']
# cirrhotic SPECIES
# ['cirrhotic SPECIES']
# an important risk factor for DISEASE
# ['an important risk factor for ', '']
# the suppression of GENE
# ['the suppression of ', '']
# CHEMICAL and derivative
# ['', ' and derivative']
# CHEMICAL d2 receptor
# ['', ' d2 receptor']
# CHEMICAL mechanism of action
# ['', ' mechanism of action']
# the case of DISEASE
# ['the case of ', '']
# DISEASE brain
# ['', ' brain']
# CHEMICAL synthase ( nos
# ['', ' synthase ( nos']
# the transcription of GENE
# ['the transcription of ', '']
# early DISEASE
# ['early ', '']
# small DISEASE
# ['small ', '']
# min/+ SPECIES
# ['min/+ SPECIES']
# the effect of CHEMICAL on growth
# ['the effect of ', ' on growth']
# DISEASE animal
# ['', ' animal']
# the growth inhibitory effect of CHEMICAL
# ['the growth inhibitory effect of ', '']
# the antitumor effect of CHEMICAL
# ['the antitumor effect of ', '']
# differentiation of DISEASE
# ['differentiation of ', '']
# SPECIES in vivo
# ['SPECIES in vivo']
# recurrent DISEASE
# ['recurrent ', '']
# the degree of DISEASE
# ['the degree of ', '']
# GENE mrna and protein ,
# ['', ' mrna and protein ,']
# DISEASE administration
# ['', ' administration']
# mrna and GENE
# ['mrna and ', '']
# background : CHEMICAL
# ['background : ', '']
# GENE abundance
# ['', ' abundance']
# analysis of DISEASE
# ['analysis of ', '']
# no effect on DISEASE
# ['no effect on ', '']
# DISEASE initiation
# ['', ' initiation']
# DISEASE and dna
# ['', ' and dna']
# the potential role of GENE
# ['the potential role of ', '']
# mutation and DISEASE
# ['mutation and ', '']
# the CHEMICAL analog
# ['the ', ' analog']
# CHEMICAL transporter
# ['', ' transporter']
# the effectiveness of CHEMICAL
# ['the effectiveness of ', '']
# inhibitory effect of CHEMICAL on expression
# ['inhibitory effect of ', ' on expression']
# activity of SPECIES
# ['activity of SPECIES']
# a role for CHEMICAL
# ['a role for ', '']
# background : GENE
# ['background : ', '']
# DISEASE survival
# ['', ' survival']
# GENE oncogene
# ['', ' oncogene']
# high GENE expression
# ['high ', ' expression']
# regulation of GENE
# ['regulation of ', '']
# a GENE mutation
# ['a ', ' mutation']
# the expression level of GENE
# ['the expression level of ', '']
# the CHEMICAL metabolism
# ['the ', ' metabolism']
# reactive CHEMICAL species
# ['reactive ', ' species']
# cardiac GENE
# ['cardiac ', '']
# intracellular GENE
# ['intracellular ', '']
# CHEMICAL induction
# ['', ' induction']
# GENE mrnas
# ['', ' mrnas']
# significant reduction in GENE
# ['significant reduction in ', '']
# tumorigenesis in SPECIES
# ['tumorigenesis in SPECIES']
# intracellular free CHEMICAL
# ['intracellular free ', '']
# sr CHEMICAL
# ['sr ', '']
# maternal CHEMICAL
# ['maternal ', '']
# inhibit DISEASE
# ['inhibit ', '']
# SPECIES polymorphonuclear leukocyte
# ['SPECIES polymorphonuclear leukocyte']
# untreated DISEASE
# ['untreated ', '']
# preterm SPECIES
# ['preterm SPECIES']
# SPECIES age
# ['SPECIES age']
# CHEMICAL requirement
# ['', ' requirement']
# SPECIES intestine
# ['SPECIES intestine']
# the increase of GENE
# ['the increase of ', '']
# ...
# ['', ' hormone level']
# GENE , as well as
# ['', ' , as well as']
# antifibrotic effect of CHEMICAL
# ['antifibrotic effect of ', '']
# treatment of SPECIES
# ['treatment of SPECIES']
# CHEMICAL dehydrogenase ( ldh
# ['', ' dehydrogenase ( ldh']
# the CHEMICAL extract
# ['the ', ' extract']
# possible DISEASE
# ['possible ', '']
# sulfate CHEMICAL
# ['sulfate ', '']
# partner GENE
# ['partner ', '']
# CHEMICAL hydrolas
# ['', ' hydrolas']
# immune DISEASE
# ['immune ', '']
# CHEMICAL i.p
# ['', ' i.p']
# the CHEMICAL derivative
# ['the ', ' derivative']
# GENE , star
# ['', ' , star']
# internalization of GENE
# ['internalization of ', '']
# less CHEMICAL
# ['less ', '']
# supplemental CHEMICAL
# ['supplemental ', '']
# GENE nuclear translocation and
# ['', ' nuclear translocation and']
# GENE gene (
# ['', ' gene (']
# comparison of CHEMICAL
# ['comparison of ', '']
# CHEMICAL significantly induce
# ['', ' significantly induce']
# inhibitory effect of GENE
# ['inhibitory effect of ', '']
# analogue CHEMICAL
# ['analogue ', '']
# GENE show
# ['', ' show']
# b ( GENE )
# ['b ( ', ' )']
# c57bl/6 SPECIES
# ['c57bl/6 SPECIES']
# protein , GENE
# ['protein , ', '']
# kg CHEMICAL ,
# ['kg ', ' ,']
# the development of DISEASE and
# ['the development of ', ' and']
# environmental exposure to CHEMICAL
# ['environmental exposure to ', '']
# GENE ) family
# ['', ' ) family']
# plasma GENE level
# ['plasma ', ' level']
# GENE , which encode
# ['', ' , which encode']
# novel GENE inhibitor
# ['novel ', ' inhibitor']
# DISEASE ) model
# ['', ' ) model']
# CHEMICAL and compound
# ['', ' and compound']
# SPECIES decrease
# ['SPECIES decrease']
# serum CHEMICAL aminotransferase
# ['serum ', ' aminotransferase']
# the DISEASE mechanism
# ['the ', ' mechanism']
# size of DISEASE
# ['size of ', '']
# suffering from DISEASE
# ['suffering from ', '']
# nano CHEMICAL
# ['nano ', '']
# tissue CHEMICAL level
# ['tissue ', ' level']
# the severe DISEASE
# ['the severe ', '']
# CHEMICAL nps
# ['', ' nps']
# experimental SPECIES model
# ['experimental SPECIES model']
# CHEMICAL and related
# ['', ' and related']
# SPECIES health risk
# ['SPECIES health risk']
# serum CHEMICAL aminotransferase and
# ['serum ', ' aminotransferase and']
# lung DISEASE and
# ['lung ', ' and']
# DISEASE as well as
# ['', ' as well as']
# the combination of CHEMICAL
# ['the combination of ', '']
# CHEMICAL assay and
# ['', ' assay and']
# that GENE mediate
# ['that ', ' mediate']
# SPECIES show
# ['SPECIES show']
# alter DISEASE
# ['alter ', '']
# DISEASE activity
# ['', ' activity']
# CHEMICAL transaminase ,
# ['', ' transaminase ,']
# incidence and severity of DISEASE
# ['incidence and severity of ', '']
# kg CHEMICAL and
# ['kg ', ' and']
# dehydrogenase and CHEMICAL
# ['dehydrogenase and ', '']
# the appearance of DISEASE
# ['the appearance of ', '']
# selective CHEMICAL reuptake inhibitor
# ['selective ', ' reuptake inhibitor']
# enzyme ( GENE )
# ['enzyme ( ', ' )']
# DISEASE ) development
# ['', ' ) development']
# CHEMICAL content and
# ['', ' content and']
# CHEMICAL exposure ,
# ['', ' exposure ,']
# SPECIES chorioallantoic membrane
# ['SPECIES chorioallantoic membrane']
# inorganic CHEMICAL ,
# ['inorganic ', ' ,']
# CHEMICAL transferase
# ['', ' transferase']
# the occurrence of DISEASE
# ['the occurrence of ', '']
# mucosa of SPECIES
# ['mucosa of SPECIES']
# GENE antagonist
# ['', ' antagonist']
# DISEASE and gene
# ['', ' and gene']
# prenatal CHEMICAL ingestion
# ['prenatal ', ' ingestion']
# number of CHEMICAL
# ['number of ', '']
# inactive CHEMICAL
# ['inactive ', '']
# potential against DISEASE
# ['potential against ', '']
# CHEMICAL mitigate
# ['', ' mitigate']
# male SPECIES (
# ['male SPECIES (']
# DISEASE dose
# ['', ' dose']
# induce DISEASE
# ['induce ', '']
# macular SPECIES
# ['macular SPECIES']
# DISEASE protein 70
# ['', ' protein 70']
# GENE decarboxylase
# ['', ' decarboxylase']
# oral dose of CHEMICAL
# ['oral dose of ', '']
# development and progression of DISEASE
# ['development and progression of ', '']
# SPECIES prefrontal cortex
# ['SPECIES prefrontal cortex']
# assessment of CHEMICAL
# ['assessment of ', '']
# that GENE bind
# ['that ', ' bind']
# combined treatment with CHEMICAL
# ['combined treatment with ', '']
# structural DISEASE
# ['structural ', '']
# DISEASE stem
# ['', ' stem']
# gene silencing of GENE
# ['gene silencing of ', '']
# GENE transcription ,
# ['', ' transcription ,']
# synergistic DISEASE
# ['synergistic ', '']
# collagen and GENE
# ['collagen and ', '']
# receptor antagonist ( CHEMICAL )
# ['receptor antagonist ( ', ' )']
# blood CHEMICAL ( bun
# ['blood ', ' ( bun']
# xenograft SPECIES model
# ['xenograft SPECIES model']
# line GENE
# ['line ', '']
# maternal DISEASE
# ['maternal ', '']
# blood CHEMICAL ,
# ['blood ', ' ,']
# activation in SPECIES
# ['activation in SPECIES']
# prenatal exposure to CHEMICAL
# ['prenatal exposure to ', '']
# SPECIES hepatocyte cell line
# ['SPECIES hepatocyte cell line']
# display DISEASE
# ['display ', '']
# ( 2 ) CHEMICAL
# ['( 2 ) ', '']
# lcn SPECIES
# ['lcn SPECIES']
# the interaction between CHEMICAL
# ['the interaction between ', '']
# SPECIES bronchial epithelial cell line
# ['SPECIES bronchial epithelial cell line']
# therapeutic strategy against DISEASE
# ['therapeutic strategy against ', '']
# GENE level
# ['', ' level']
# CHEMICAL resistance
# ['', ' resistance']
# SPECIES vascular
# ['SPECIES vascular']
# role for CHEMICAL
# ['role for ', '']
# ) polymerase ( GENE )
# [') polymerase ( ', ' )']
# GENE ) signaling pathway
# ['', ' ) signaling pathway']
# the SPECIES ortholog
# ['the SPECIES ortholog']
# association between GENE
# ['association between ', '']
# CHEMICAL metabolic pathway
# ['', ' metabolic pathway']
# family GENE
# ['family ', '']
# DISEASE model group
# ['', ' model group']
# CHEMICAL dependent
# ['', ' dependent']
# intoxicated SPECIES
# ['intoxicated SPECIES']
# CHEMICAL increase ,
# ['', ' increase ,']
# GENE reductase
# ['', ' reductase']
# initiation and progression of DISEASE
# ['initiation and progression of ', '']
# remodeling and DISEASE
# ['remodeling and ', '']
# 1 ) CHEMICAL
# ['1 ) ', '']
# CHEMICAL or vehicle
# ['', ' or vehicle']
# CHEMICAL kinase (
# ['', ' kinase (']
# CHEMICAL ( control
# ['', ' ( control']
# metabolism in SPECIES
# ['metabolism in SPECIES']
# SPECIES oil
# ['SPECIES oil']
# ( CHEMICAL ) receptor
# ['( ', ' ) receptor']
# SPECIES ovarian
# ['SPECIES ovarian']
# CHEMICAL oxidase (
# ['', ' oxidase (']
# major CHEMICAL
# ['major ', '']
# CHEMICAL alleviate
# ['', ' alleviate']
# intracellular CHEMICAL ,
# ['intracellular ', ' ,']
# CHEMICAL protect
# ['', ' protect']
# CHEMICAL flame retardant
# ['', ' flame retardant']
# kinase inhibitor CHEMICAL
# ['kinase inhibitor ', '']
# a natural CHEMICAL compound
# ['a natural ', ' compound']
# SPECIES ash
# ['SPECIES ash']
# the CHEMICAL level and
# ['the ', ' level and']
# associated DISEASE
# ['associated ', '']
# CHEMICAL share
# ['', ' share']
# anticancer activity of CHEMICAL
# ['anticancer activity of ', '']
# extract of SPECIES
# ['extract of SPECIES']
# ( CHEMICAL ) level ,
# ['( ', ' ) level ,']
# SPECIES albino
# ['SPECIES albino']
# the GENE level
# ['the ', ' level']
# GENE ) function
# ['', ' ) function']
# CHEMICAL depletion and
# ['', ' depletion and']
# obvious DISEASE
# ['obvious ', '']
# the development of DISEASE
# ['the development of ', '']
# CHEMICAL solution
# ['', ' solution']
# GENE inflammasome activation
# ['', ' inflammasome activation']
# enzyme ( GENE
# ['enzyme ( ', '']
# namely GENE
# ['namely ', '']
# particularly GENE
# ['particularly ', '']
# GENE administration
# ['', ' administration']
# cycle inhibitor GENE
# ['cycle inhibitor ', '']
# protein kinase GENE
# ['protein kinase ', '']
# DISEASE cell growth and
# ['', ' cell growth and']
# gene mutation in SPECIES
# ['gene mutation in SPECIES']
# observed DISEASE
# ['observed ', '']
# treatment ( CHEMICAL
# ['treatment ( ', '']
# weight , CHEMICAL
# ['weight , ', '']
# ppary and GENE
# ['ppary and ', '']
# SPECIES fish
# ['SPECIES fish']
# 15 SPECIES
# ['15 SPECIES']
# externalization of CHEMICAL
# ['externalization of ', '']
# toxin CHEMICAL
# ['toxin ', '']
# synergy between CHEMICAL
# ['synergy between ', '']
# the mrna expression of GENE ,
# ['the mrna expression of ', ' ,']
# the group of SPECIES
# ['the group of SPECIES']
# pathogenesis of CHEMICAL
# ['pathogenesis of ', '']
# DISEASE promote
# ['', ' promote']
# single oral dose of CHEMICAL
# ['single oral dose of ', '']
# disruption in SPECIES
# ['disruption in SPECIES']
# m CHEMICAL )
# ['m ', ' )']
# GENE repress
# ['', ' repress']
# insulin and CHEMICAL
# ['insulin and ', '']
# either CHEMICAL ,
# ['either ', ' ,']
# stress and GENE
# ['stress and ', '']
# silence of GENE
# ['silence of ', '']
# CHEMICAL antibiotic
# ['', ' antibiotic']
# stress , DISEASE
# ['stress , ', '']
# fungicide CHEMICAL
# ['fungicide ', '']
# CHEMICAL reactive substance (
# ['', ' reactive substance (']
# unassigned : CHEMICAL
# ['unassigned : ', '']
# cellular CHEMICAL level
# ['cellular ', ' level']
# DISEASE +
# ['', ' +']
# repress GENE
# ['repress ', '']
# GENE mrna level and
# ['', ' mrna level and']
# CHEMICAL impair
# ['', ' impair']
# secretion of GENE
# ['secretion of ', '']
# protective effect of SPECIES
# ['protective effect of SPECIES']
# GENE level and
# ['', ' level and']
# several SPECIES
# ['several SPECIES']
# antibiotic CHEMICAL
# ['antibiotic ', '']
# unassigned : GENE
# ['unassigned : ', '']
# combined treatment with CHEMICAL and
# ['combined treatment with ', ' and']
# SPECIES aged
# ['SPECIES aged']
# SPECIES hippocampus
# ['SPECIES hippocampus']
# CHEMICAL equivalent
# ['', ' equivalent']
# DISEASE formation and
# ['', ' formation and']
# pathway by CHEMICAL
# ['pathway by ', '']
# affinity for CHEMICAL
# ['affinity for ', '']
# CHEMICAL administration in
# ['', ' administration in']
# inhibited GENE
# ['inhibited ', '']
# CHEMICAL dismutase ( sod
# ['', ' dismutase ( sod']
# DISEASE , as well as
# ['', ' , as well as']
# reproductive DISEASE of
# ['reproductive ', ' of']
# CHEMICAL screen
# ['', ' screen']
# CHEMICAL aminotransferase and
# ['', ' aminotransferase and']
# high CHEMICAL
# ['high ', '']
# treatment SPECIES
# ['treatment SPECIES']
# exposure to CHEMICAL ,
# ['exposure to ', ' ,']
# hepatotoxicity of CHEMICAL
# ['hepatotoxicity of ', '']
# expression , DISEASE
# ['expression , ', '']
# day CHEMICAL
# ['day ', '']
# link to DISEASE
# ['link to ', '']
# CHEMICAL formation and
# ['', ' formation and']
# absence or presence of CHEMICAL
# ['absence or presence of ', '']
# SPECIES cause
# ['SPECIES cause']
# setting of DISEASE
# ['setting of ', '']
# CHEMICAL toxicity
# ['', ' toxicity']
# elicit DISEASE
# ['elicit ', '']
# b and GENE
# ['b and ', '']
# the CHEMICAL treatment
# ['the ', ' treatment']
# DISEASE threshold
# ['', ' threshold']
# CHEMICAL metabolism and
# ['', ' metabolism and']
# intravenous infusion of CHEMICAL
# ['intravenous infusion of ', '']
# CHEMICAL diminish
# ['', ' diminish']
# CHEMICAL mustard (
# ['', ' mustard (']
# DISEASE modulate
# ['', ' modulate']
# drug CHEMICAL
# ['drug ', '']
# acute DISEASE and
# ['acute ', ' and']
# CHEMICAL rescue
# ['', ' rescue']
# the GENE receptor and
# ['the ', ' receptor and']
# hormone , CHEMICAL
# ['hormone , ', '']
# CHEMICAL peroxidase , and
# ['', ' peroxidase , and']
# treatment of DISEASE
# ['treatment of ', '']
# CHEMICAL interfere
# ['', ' interfere']
# intermittent DISEASE
# ['intermittent ', '']
# a group of SPECIES
# ['a group of SPECIES']
# the drug CHEMICAL
# ['the drug ', '']
# animal and SPECIES
# ['animal and SPECIES']
# CHEMICAL 2
# ['', ' 2']
# SPECIES subject
# ['SPECIES subject']
# the CHEMICAL dose
# ['the ', ' dose']
# low CHEMICAL
# ['low ', '']
# CHEMICAL model
# ['', ' model']
# the CHEMICAL model
# ['the ', ' model']
# ingestion of CHEMICAL
# ['ingestion of ', '']
# CHEMICAL stimulation
# ['', ' stimulation']
# SPECIES specie
# ['SPECIES specie']
# CHEMICAL release
# ['', ' release']
# natural CHEMICAL
# ['natural ', '']
# chemoprevention of DISEASE
# ['chemoprevention of ', '']
# synthetic CHEMICAL
# ['synthetic ', '']
# the onset of DISEASE
# ['the onset of ', '']
# CHEMICAL damage
# ['', ' damage']
# this model of DISEASE
# ['this model of ', '']
# normotensive SPECIES
# ['normotensive SPECIES']
# the heart of SPECIES
# ['the heart of SPECIES']
# cultured DISEASE cell
# ['cultured ', ' cell']
# a DISEASE cell line
# ['a ', ' cell line']
# SPECIES leukocyte
# ['SPECIES leukocyte']
# the therapy of DISEASE
# ['the therapy of ', '']
# pretreatment with CHEMICAL
# ['pretreatment with ', '']
# the modulation of GENE
# ['the modulation of ', '']
# GENE interaction
# ['', ' interaction']
# CHEMICAL derivative
# ['', ' derivative']
# bovine GENE
# ['bovine ', '']
# insulin , CHEMICAL
# ['insulin , ', '']
# renal CHEMICAL
# ['renal ', '']
# CHEMICAL protease
# ['', ' protease']
# a hallmark of DISEASE
# ['a hallmark of ', '']
# SPECIES hippocampal neuron
# ['SPECIES hippocampal neuron']
# CHEMICAL poisoning
# ['', ' poisoning']
# a mixture of CHEMICAL
# ['a mixture of ', '']
# CHEMICAL and agonist
# ['', ' and agonist']
# the case of SPECIES
# ['the case of SPECIES']
# the incidence of DISEASE
# ['the incidence of ', '']
# CHEMICAL tolerance
# ['', ' tolerance']
# the risk of DISEASE
# ['the risk of ', '']
# CHEMICAL user
# ['', ' user']
# normal SPECIES
# ['normal SPECIES']
# influence of DISEASE
# ['influence of ', '']
# plasma of SPECIES
# ['plasma of SPECIES']
# DISEASE alone
# ['', ' alone']
# the SPECIES embryo
# ['the SPECIES embryo']
# liver CHEMICAL
# ['liver ', '']
# CHEMICAL assay
# ['', ' assay']
# cutaneous DISEASE
# ['cutaneous ', '']
# free CHEMICAL
# ['free ', '']
# activation of CHEMICAL
# ['activation of ', '']
# CHEMICAL and water
# ['', ' and water']
# the content of CHEMICAL
# ['the content of ', '']
# essential CHEMICAL
# ['essential ', '']
# primary culture of SPECIES
# ['primary culture of SPECIES']
# stimulation of GENE
# ['stimulation of ', '']
# GENE oxidation
# ['', ' oxidation']
# DISEASE and control
# ['', ' and control']
# low GENE
# ['low ', '']
# lung of SPECIES
# ['lung of SPECIES']
# CHEMICAL precursor
# ['', ' precursor']
# SPECIES tissue
# ['SPECIES tissue']
# CHEMICAL at concentration
# ['', ' at concentration']
# deficiency of GENE
# ['deficiency of ', '']
# the severity of DISEASE
# ['the severity of ', '']
# systemic CHEMICAL
# ['systemic ', '']
# CHEMICAL activity
# ['', ' activity']
# effect and mechanism of CHEMICAL
# ['effect and mechanism of ', '']
# exception of CHEMICAL
# ['exception of ', '']
# the injection of CHEMICAL
# ['the injection of ', '']
# the application of CHEMICAL
# ['the application of ', '']
# cultured SPECIES
# ['cultured SPECIES']
# urinary excretion of CHEMICAL
# ['urinary excretion of ', '']
# DISEASE release
# ['', ' release']
# thymic DISEASE
# ['thymic ', '']
# CHEMICAL peroxidase
# ['', ' peroxidase']
# b6c3f1 SPECIES
# ['b6c3f1 SPECIES']
# vivo administration of CHEMICAL
# ['vivo administration of ', '']
# the regulation of CHEMICAL
# ['the regulation of ', '']
# CHEMICAL group
# ['', ' group']
# GENE transporter
# ['', ' transporter']
# the decrease in GENE
# ['the decrease in ', '']
# unrelated SPECIES
# ['unrelated SPECIES']
# the CHEMICAL terminus
# ['the ', ' terminus']
# GENE reductase activity
# ['', ' reductase activity']
# ( GENE ) expression
# ['( ', ' ) expression']
# CHEMICAL oxidase ,
# ['', ' oxidase ,']
# the GENE promoter
# ['the ', ' promoter']
# the effect of CHEMICAL on activation
# ['the effect of ', ' on activation']
# elevation of GENE
# ['elevation of ', '']
# reactive CHEMICAL specie
# ['reactive ', ' specie']
# CHEMICAL antagonism
# ['', ' antagonism']
# the survival of SPECIES
# ['the survival of SPECIES']
# the toxic effect of CHEMICAL
# ['the toxic effect of ', '']
# DISEASE biology
# ['', ' biology']
# malignant DISEASE
# ['malignant ', '']
# solid DISEASE
# ['solid ', '']
# factor ( GENE
# ['factor ( ', '']
# plasma concentration of GENE
# ['plasma concentration of ', '']
# the lung of SPECIES
# ['the lung of SPECIES']
# GENE mrna expression
# ['', ' mrna expression']
# ( GENE ) gene
# ['( ', ' ) gene']
# GENE transferase
# ['', ' transferase']
# the production of CHEMICAL
# ['the production of ', '']
# expression of CHEMICAL
# ['expression of ', '']
# production of CHEMICAL
# ['production of ', '']
# inhibitor of GENE
# ['inhibitor of ', '']
# inducible CHEMICAL synthase
# ['inducible ', ' synthase']
# contrast to SPECIES
# ['contrast to SPECIES']
# SPECIES alveolar macrophage
# ['SPECIES alveolar macrophage']
# GENE mrna and
# ['', ' mrna and']
# CHEMICAL inhalation
# ['', ' inhalation']
# GENE ratio
# ['', ' ratio']
# CHEMICAL addition
# ['', ' addition']
# CHEMICAL d2
# ['', ' d2']
# the antiproliferative effect of CHEMICAL
# ['the antiproliferative effect of ', '']
# CHEMICAL synthase ( nos )
# ['', ' synthase ( nos )']
# CHEMICAL reductase
# ['', ' reductase']
# CHEMICAL tension
# ['', ' tension']
# administration of GENE
# ['administration of ', '']
# pretreatment with GENE
# ['pretreatment with ', '']
# CHEMICAL free radical
# ['', ' free radical']
# development of DISEASE
# ['development of ', '']
# accumulation of GENE
# ['accumulation of ', '']
# i.e. , GENE
# ['i.e. , ', '']
# the presence of DISEASE
# ['the presence of ', '']
# topical CHEMICAL
# ['topical ', '']

# %%
# re
re.search("%", "wh ehiu ) ().., %,")
# Out:
# <_sre.SRE_Match object; span=(16, 17), match='%'>

# %%
pattern = []
with open("train_CRAFT_cnt_N_p.tsv", "r") as f:
    for line in f:
        segs = line[:-1].split("\t")  # delete the '\n' at the end of each line
        if(len(segs)!=3):
            #print(line)
            pass
        else:
            pattern.append(segs)
print (pattern)
print ("finish loading structure pattern: ", len(pattern))
# Out:
# [['$W$$N$', 'GENE', '11849'], ['$W$ - $W$', 'GENE', '2959'], ['$W$ - $N$', 'GENE', '2844'], ['$W$$N$', 'Chemical', '2239'], ['$W$ - $W$', 'Chemical', '1789'], ['$W$$N$$W$', 'GENE', '1438'], ['$W$$N$ $W$', 'GENE', '1339'], ['$W$ - $W$ $W$', 'GENE', '1118'], ['$N$ - $W$', 'Chemical', '986'], ['$W$ - $N$ $W$', 'GENE', '892'], ['$W$$N$$W$$N$', 'GENE', '691'], ['$W$ - $N$', 'Chemical', '679'], ['$W$ $W$$N$', 'GENE', '664'], ['$W$ ( $N$ )', 'Chemical', '533'], ['$W$ ( $N$ + )', 'Chemical', '522'], ['$W$ ( $W$ )', 'Chemical', '406'], ['$W$ - $W$ $W$ $W$', 'GENE', '383'], ['( $N$ ) $W$', 'Chemical', '316'], ['$W$ - $W$ $W$', 'Chemical', '274'], ['$W$ $N$', 'GENE', '266'], ['$W$$N$$W$', 'Chemical', '265'], ['$W$$N$$W$$N$', 'Chemical', '258'], ['$W$$N$ $W$ $W$', 'GENE', '254'], ['$W$ $W$ - $W$ $W$', 'GENE', '250'], ['$W$ ( + )', 'Chemical', '236'], ['$W$ $N$', 'Chemical', '230'], ['$W$ $W$$N$', 'Chemical', '194'], ['$W$ - $N$$W$', 'GENE', '185'], ['$W$ - $W$ - $W$', 'Chemical', '182'], ['$W$ $W$ $N$', 'GENE', '173'], ['$N$$W$', 'Chemical', '169'], ['$W$$N$$W$ $W$', 'GENE', '167'], ['$W$ $W$$N$ $W$', 'GENE', '163'], ['$N$ , $N$ - $W$', 'Chemical', '163'], ['$W$ - $W$$N$', 'GENE', '159'], ['$W$ $W$ - $W$', 'GENE', '148'], ['$W$ - $W$ $N$', 'GENE', '146'], ['$W$ ( $N$ ) $W$ ( $N$ )', 'Chemical', '136'], ['$W$ $W$ - $N$', 'GENE', '135'], ['$N$ - $W$ - $W$', 'Chemical', '134'], ['$N$$W$$N$', 'GENE', '134'], ['$W$ $W$ $W$$N$', 'GENE', '128'], ['$W$$N$ +', 'Chemical', '126'], ['$W$ $W$ $W$ $N$', 'GENE', '125'], ['$W$$N$$W$$N$ $W$', 'GENE', '117'], ['$W$$N$ / $N$', 'GENE', '117'], ['$W$ $W$ $W$ - $W$', 'GENE', '114'], ['$N$ $W$ - $W$', 'Chemical', '113'], ['$N$ - $W$ $W$', 'Chemical', '111'], ['$W$ $W$ $W$ - $N$', 'GENE', '107'], ['$W$$N$ - $W$', 'GENE', '106'], ['$W$ $W$ - $W$', 'Chemical', '106'], ['$W$ +', 'Chemical', '104'], ['$W$ $N$ - $W$', 'GENE', '98'], ['$W$ - $N$ - $W$', 'Chemical', '95'], ['$W$$N$ - $N$', 'GENE', '88'], ['$W$ / $W$ $W$', 'GENE', '84'], ['$N$ - $W$ - $N$ - $W$', 'Chemical', '84'], ['$W$ - $W$ - $W$ - $W$', 'Chemical', '83'], ['( - ) - $W$', 'Chemical', '81'], ['$W$ ( $W$ $W$ )', 'Chemical', '80'], ['$W$ - $W$ $W$ $W$ $W$', 'GENE', '78'], ['$W$ - $N$ $W$ $W$', 'GENE', '78'], ['$W$ ( $N$ )', 'GENE', '78'], ['$W$ ( $W$ ) $W$', 'Chemical', '78'], ['$W$ $W$ - $W$ $W$ $W$', 'GENE', '76'], ['$W$$N$ - $W$ $W$', 'GENE', '74'], ['$W$$N$ . $N$', 'GENE', '69'], ['$W$ ( $W$ )', 'GENE', '69'], ['$W$ ( $N$ ) $W$', 'Chemical', '68'], ['$W$ ( - )', 'Chemical', '66'], ['$W$ / $W$', 'GENE', '65'], ['$W$ - $W$ - $W$ $W$', 'GENE', '63'], ['$W$ - $W$ - $W$', 'GENE', '62'], ['$W$ $N$ $W$', 'GENE', '61'], ['[ ( $N$ ) $W$ ] $W$', 'Chemical', '58'], ['$W$$N$ ( + )', 'GENE', '57'], ['$W$ $W$ $W$ $W$ $N$', 'GENE', '53'], ['$W$ - $W$ - $N$', 'GENE', '52'], ['$W$ ( $N$ ) $W$', 'GENE', '52'], ['$W$$N$ $W$ $W$ $W$', 'GENE', '51'], ['$W$ $W$ $W$ $W$$N$', 'GENE', '50'], ['$W$ - $W$ $W$ - $W$ $W$', 'GENE', '48'], ['$W$ $W$ $W$ - $W$ $W$', 'GENE', '47'], ['$W$$N$ - $N$', 'Chemical', '47'], ['$W$ - $W$$N$', 'Chemical', '47'], ['$N$ , $N$ - $W$ - $N$ - $W$', 'Chemical', '47'], ['$W$ [ $W$ ] $W$', 'Chemical', '44'], ['$W$ - $W$ $W$ $W$', 'Chemical', '44'], ['$N$$W$', 'GENE', '43'], ["$N$ ' - $W$", 'Chemical', '43'], ['$W$$N$ +', 'GENE', '41'], ['$N$$W$ - $W$', 'Chemical', '41'], ['$W$ ( $W$ - $W$ )', 'Chemical', '41'], ['$N$$W$ $W$', 'GENE', '40'], ['$W$$N$ - $W$$N$', 'GENE', '40'], ['$W$ - $W$ $W$ $N$', 'GENE', '39'], ['$W$ - $N$$W$', 'Chemical', '38'], ['$W$ $W$ $N$ $W$', 'GENE', '37'], ['$W$ $W$$N$$W$', 'GENE', '36'], ['$W$ - $W$ $W$ - $N$', 'GENE', '35'], ['$N$ - $W$$N$$W$ $W$', 'GENE', '35'], ['$N$ , $N$ - $W$ $W$', 'Chemical', '35'], ['$W$ - $W$ $W$$N$', 'GENE', '34'], ['$W$ $W$ ( $N$ )', 'Chemical', '33'], ['$W$ ( $W$ ) $W$', 'GENE', '32'], ['$N$ - $W$', 'GENE', '32'], ['$N$ , $N$ , $N$ - $W$', 'Chemical', '32'], ['$W$$N$ ( - / - )', 'GENE', '32'], ['$W$ [ $N$ , $N$ - $W$ ] $W$', 'Chemical', '32'], ['$W$$N$$W$ $W$ $W$', 'GENE', '31'], ['$W$ $W$ - $N ...
# finish loading structure pattern:  3773

# %%
re.search(r"and/or", r"we have and/or")
# Out:
# <_sre.SRE_Match object; span=(8, 14), match='and/or'>

# %% [markdown]
# # Structure Patterns

# %%
re.search('[-+]?[0-9]+', "this is a -45 . 89 word")
# Out:
# <_sre.SRE_Match object; span=(10, 13), match='-45'>

# %%
re.search('\w+[-+]?[0-9]+', "Bl3")
# Out:
# <_sre.SRE_Match object; span=(0, 3), match='Bl3'>

# %%
with open("train1_all.tsv", "r") as f:
    a = []
    for line in f:
        segs= line.split("\t")
        if(len(segs)>2):
            print(line)
        if("-" in segs[0]):
            a.append(segs[0])
set(a)
# Out:
# {'+/-', '-->', '-1', '-2', '-3', '19-Apr', '2-Oct', '4-Oct', '<--', '=-'}

# %%
with open("train0_all.tsv", "r") as f:
    a = []
    for line in f:
        segs= line.split("\t")
        if(len(segs)>2):
            print(line)
        if("-" in segs[0]):
            a.append(segs[0])
set(a)
# Out:
# {'1-Oct', '2-Oct', '3-Oct', '4-Oct', '=-', 'Oct-91'}

# %%
with open("train_CRAFT.tsv", "r") as f:
    a = []
    for line in f:
        segs= line.split("\t")
        if(len(segs)>2):
            print(line)
        if("-" in segs[0]):
            a.append(segs[0])
set(a)
# Out:
# {'+/-', '-', '--', '-->', '<-->'}

# %%
with open("train_CRAFT.tsv", "r") as f:
    tmp = []
    type_e = []
    for line in f:
        segs = line.split("\t")
        if(len(segs)==2):
            if(segs[1]=="O\n"):
                if(len(tmp)>0):
                    print(" ".join(tmp))
                tmp = []
            else:
                tmp.append(segs[0])
                type_e.append(segs[1][:-1])
# Abcg8
# Abcg5
# nt
# Abcg8
# nt
# mRNA
# UNG enzyme
# UNG
# mRNA
# lipid
# protein
# Abcg8
# Abcg8
# Abcg8
# EDTA
# protein
# Sterol
# chow
# Abcg8
# Abcg8
# Abcg8
# NaOH
# water
# sterols
# ethyl acetate
# 5 alpha - cholestane
# phosphate buffer
# protein
# sterol
# sterol
# hexane
# sterols
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# protein
# Tris
# sucrose
# protease inhibitors
# Protein
# protein
# proteins
# SDS acrylamide
# Proteins
# SDS
# Phosphate Buffered
# Abcg5
# Tris Buffered
# NaCl
# NaCl
# Reagent
# methanol
# glycine
# sterolin - 1
# acetone
# sterolin - 1
# Bsep
# Abcg5
# Bsep
# mouse Abcg5
# mouse Abcg8
# CO2
# penicillin
# streptomycin
# glutamine
# acetone
# methanol
# Abcg5
# lipid
# Diazepam
# bile salt
# sterol
# phospholipid
# lipid
# bile salt
# Chemical
# bile salt
# lipid
# Sterol
# HMG - CoA
# cholesterol 7 alpha - hydroxylase
# sucrose
# Tris
# EDTA
# DTT
# phosphate
# KCl
# DTT
# EDTA
# glycerol
# protein
# Protein
# cholesterol 7 alpha - hydroxylase
# potassium phosphate
# EDTA
# DTT
# nicotinamide
# 14C
# cholesterol
# cyclodextrin
# protein
# NADPH
# NADPH
# NADP +
# glucose - 6 - phosphate
# glucose - 6 - phosphate dehydrogenase
# KOH
# hydroxytoluene
# ethanolic potassium hydroxide
# 3H
# 7 alpha - hydroxycholesterol
# sterols
# n - hexane
# nitrogen
# n - hexane
# 2 - propanol
# silica
# n - hexane
# 2 - propanol
# 7 alpha - hydroxycholesterol
# n - hexane
# 2 - propanol
# silica
# Silica
# diethyl ether
# HMG - CoA reductase
# Abcg8
# sterolin - 2
# mRNA
# Abcg8
# Abcg5
# Abcg8
# sterolin - 2 protein
# Abcg5
# sterolin - 1
# Abcg8
# mRNA
# Abcg8
# sterolin - 2
# Abcg8
# protein
# Abcg8
# Abcg8
# sterolin - 2
# Sterol
# Abcg8
# sterolin - 2
# plant sterols
# Sterol
# Abcg8
# cholesterol
# Plant sterols
# Abcg8
# campesterol
# sitosterol
# Abcg8
# plant sterol
# cholesterol
# Abcg8
# cholesterol
# campesterol
# sitosterol
# Abcg8
# cholesterol
# plant sterol
# Abcg8
# Abcg8
# sterol
# sterol
# sterols
# plant sterols
# plant sterols
# Abcg8
# cholesterol
# sitosterol
# campesterol
# sterol
# sterols
# sterols
# sterols
# triglycerides
# chow
# sterol
# Abcg8
# triglyceride
# LDL lipoprotein
# triglyceride
# Abcg8
# proteins
# apolipoproteins B , E , AI , or AII
# triglyceride
# Abcg8
# sterolin - 2
# Abcg8
# sterolin - 2
# sterol
# Abcg5
# Abcg8
# Hmgr
# Cyp7a1
# Abca1
# Mdr2
# Lxr
# Srebp - 1c
# Srebp - 2 mRNA
# chow
# Abcg8 mRNA
# Abcg8
# mRNA
# Abcg5
# HMG - CoA reductase mRNA
# mRNA
# HMG - CoA reductase
# Cyp7a1
# HMG - CoA reductase
# Abcg8
# Abcg8
# mRNA
# Cyp7a1 mRNA
# Cyp7a1
# mRNA
# Cyp7a1
# Sitosterol
# inhibitor
# Cyp7a1
# plant sterols
# Abcg5 protein
# Abcg8
# Abcg8
# sterolin - 2
# Abcg5
# sterolin - 1
# mouse Abcg8 / sterolin - 2
# mouse Abcg5 / sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# protein
# protein
# Abcg5
# sterolin - 1
# Endo - H
# PNGaseF
# transferrin
# Abcg5
# sterolin - 1
# Endo - H
# PNGase F
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# mouse Abcg5 / sterolin - 1
# mouse Abcg8 / sterolin - 2
# Abcg5
# Abcg8
# Abcg8
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# Abcb11
# bile salts
# Abcg5
# sterolin - 1
# proteins
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# bile salts
# sterol
# phospholipids
# Abcg8
# sterolin - 2
# cholesterol
# plant sterols
# sterol
# sterol
# phospholipid
# Abcg8
# bile salt
# sterol
# phospholipid
# sterol
# sterol
# bile salt
# bile salt
# phospholipid
# phospholipid
# sterol
# sterol
# sitosterol
# cholesterol
# sterol
# sterol
# Abcg8
# sterolin - 2
# cholesterol
# sterol
# Abcg8
# sterols
# sterol
# bile acid
# cholesterol
# sitosterol
# campesterol
# Abcg8
# sterols
# cholesterol
# cholesterol sterols
# sterols
# Abcg8
# sitosterol
# HMG - CoA reductase
# CYP7a1
# mRNA
# bile acid
# CYP7a1
# mRNA
# sitosterol
# inhibitor of this enzyme
# sterols
# Abcg8
# sterol
# Abcg8
# sterol
# bile acids
# Abcg8
# sterolin - 2
# cholesterol
# sitosterol
# sitosterol
# sitosterol
# sitosterol
# plant sterols
# Abcg8
# sterolin - 2
# Abcg8
# bile salt
# phospholipid
# Abcg8
# sterolin - 2
# cholesterol
# Abcg8
# chow
# plant sterol
# Abcg8
# Abcg5
# Abcg8
# cholesterol
# triglyceride
# Abcg8
# triglyceride
# LDL
# SDS
# cholesterol
# Abcg8
# mRNA
# HMG - CoA reductase
# mRNA
# plant sterols
# Sitosterol
# Cyp7a1
# sitosterol
# mRNA
# mRNA
# cholesterol
# sitosterol
# sterols
# Abcg8
# sterolin - 2
# protein
# sterol
# sterol
# bile salt
# Abcg8
# sterolin - 2
# Abcg8
# sterolin - 2
# cholesterol
# plant sterol
# sterol
# sitosterol
# sitosterol
# sterols
# ABCG5
# ABCG8
# Abcg8
# sterolin - 2
# sterol
# chow
# sitosterol
# proteins
# Abcg8
# sitosterol
# sterol
# proteins
# plant sterol
# plant sterol
# sterol
# Abcg5
# Abcg8 mRNA
# cholesterol
# cholesterol
# mRNA
# Abcg5
# Abcg8
# protein
# Abcg5
# Abcg8
# cholesterol
# cholesterol
# Abcg8
# sterolin - 2
# plant sterol
# plant sterol
# plant sterol
# sterol
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Abcg8
# sterolin - 2
# Abcg8
# sterolin - 2
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# Abcg5
# Abcg8
# proteins
# liver X receptor alpha
# LXR alpha
# agonist
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Abcg5
# sterolin - 1
# SPNT
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# proteins
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# cholesterol
# agonist
# Abcg8 mRNA
# cholesterol
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# sterols
# Abcg5
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# proteins
# sterols
# Abcg8
# sterolin - 2
# cholesterol
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Abcg8
# sterolin - 2
# cholesterol
# sitosterol
# Abcg8
# sterolin - 2
# sitosterol
# molecular
# molecular
# sterol
# Bsep
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Abcg8
# 32P
# Abcg8
# sterolin - 2 mRNA
# Abcg8
# sterolin - 2 mRNA
# Abcg5
# sterolin - 1 mRNA
# Abcg5
# Abcg8
# Abcg8
# sterolin - 2
# Abcg8
# sterol
# Abcg8
# Abcg8
# Abcg8
# Sterol
# chow
# sterols
# cholesterol
# sitosterol
# Abcg8
# Abcg8
# Abcg8
# campesterol
# Lipid
# Abcg8
# Abcg8
# Abcg8
# Lipoproteins
# sterols
# triglyceride
# cholesterol
# triglyceride
# Abcg8
# LDL
# mRNA
# mRNA
# Abcg5
# Abcg8
# Hmgr
# Cyp7a1
# Abca1
# Mdr2
# Lxr
# Srebp - 1c
# Srebp - 2
# Abcg8
# Abcg8
# Abcg8
# mRNA
# Abcg5
# sterolin - 1
# HMG CoA reductase
# Abcg8
# sterolin - 2
# HMG - CoA reductase
# CYP7a1
# Abcg8
# Abcg8
# Abcg8
# HMG - CoA reductase
# CYP7a1
# Abcg8
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# Endo - H
# PNGaseF
# transferrin
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# Abcg8
# Endo - H
# PNGaseF
# molecular
# protein
# Abcg5
# Abcg8
# mouse Abcg5 / sterolin - 1
# mouse Abcg5
# mouse Abcg8
# Abcg5
# sterolin - 1
# Abcg5
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# Abcg5
# Abcg8
# Abcg5
# sterolin - 1
# Abcg5
# Abcg5
# sterolin - 1
# Abcg8
# Abcg8
# Abcg5
# sterolin - 1
# Abcg8
# sterolin - 2
# Bsep
# Abcb11
# Abcg8
# Abcg5
# sterolin - 1
# Abcg8
# Bsep
# Abcb11
# mouse Abcg5 / sterolin - 1
# Abcg5
# sterolin - 1
# Abcg8
# Abcg5
# sterolin - 1
# sterol
# phospholipid
# bile salt
# Bile salt
# sterol
# phospholipid
# Abcg8
# Abcg8
# Abcg8
# Bile salt
# Abcg8
# Abcg8
# sterol
# phospholipid
# Abcg8
# bile salt
# sterol
# phospholipid
# Abcg8
# Abcg8
# Abcg8
# bile salt
# Abcg8
# bile salts
# sterols
# phospholipid
# cholesterol
# sitosterol
# sterols
# Abcg8
# Abcg8
# Abcg8
# bile salt
# Abcg8
# cholesterol
# Abcg8
# sitosterol
# campesterol
# sterols
# sterol
# KCNJ10 protein
# SLC26A4
# pendrin
# pendrin
# Slc26a4
# Slc26a4
# Slc26a4
# pendrin
# proteins
# mRNA
# K +
# Pendrin
# Slc26a4
# Slc26a4
# K +
# KCNJ10
# free radical
# KCNJ10 mRNA
# KCNJ10 protein
# K +
# proteins
# K +
# K +
# KCNQ1
# KCNE1
# Na +
# K +
# SLC12A2
# GJB2
# pendrin
# KCNJ10 protein
# PDS
# SLC26A4
# protein pendrin
# iodide
# iodide
# perchlorate
# Pendrin
# anion
# Cl -
# I -
# HCO3 -
# formate
# pendrin
# pendrin mRNA
# pendrin protein
# pendrin
# pendrin
# proteins
# pendrin
# Slc26a4
# mouse Slc26a4
# pendrin
# Slc26a4
# K +
# Slc26a4
# Slc26a4
# pendrin
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# proteins
# K +
# K +
# sodium pentobarbital
# Cl -
# phosphate
# buffered Na
# gluconate
# EDTA
# sucrose
# polyethylene glycol
# bovine serum albumin
# BSA
# pendrin
# ZO - 1
# KCNQ1
# KCNE1
# KCNJ10
# SLC12A2
# connexin 26
# Molecular
# phalloidin
# Molecular
# sodium pentobarbital
# N2
# Slc26a4
# Molecular
# mRNA
# K +
# KCNJ10
# KCNQ1
# KCNQ4
# agarose
# molecules
# sodium pentobarbital
# sodium salt
# K +
# K +
# cation
# K +
# Na +
# K +
# Na +
# K +
# Na +
# Na +
# Na +
# K +
# pendrin mRNA
# pendrin protein
# Slc26a4
# pendrin
# pendrin
# HCO3 -
# Pendrin
# HCO3 -
# HCO3 -
# CO2
# carbonic
# CO2
# pendrin
# HCO3 -
# HCO3 -
# pendrin
# HCO3 -
# Protein
# pendrin
# KCNQ1
# ZO - 1
# Slc26a4
# Slc26a4
# pendrin
# KCNQ1
# K +
# ZO - 1
# protein
# pendrin
# pendrin mRNA
# pendrin protein
# KCNQ1
# pendrin
# KCNQ1
# KCNE1
# pendrin
# Slc26a4
# Slc26a4
# Slc26a4
# K +
# Slc26a4
# K +
# Slc26a4
# K +
# Slc26a4
# Slc26a4
# Slc26a4
# K +
# Slc26a4
# Slc26a4
# Slc26a4
# K +
# Slc26a4
# Slc26a4
# K +
# Slc26a4
# Slc26a4
# K +
# KCNJ10
# K +
# K +
# KCNJ10 K + channel
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# KCNJ10 mRNA
# rRNA molecules
# rRNA
# Slc26a4
# rRNA
# Slc26a4
# rRNA
# KCNJ10 mRNA
# Slc26a4
# Slc26a4
# KCNQ1
# KCNQ4 mRNA
# KCNQ1
# KCNQ4
# KCNQ1 mRNA molecules
# KCNQ4 mRNA molecules
# KCNJ10
# KCNQ1
# KCNJ10
# KCNQ1 mRNA
# Slc26a4
# Slc26a4
# Slc26a4
# 18S
# KCNJ10
# KCNQ1
# KCNQ4
# KCNJ10
# KCNQ1 mRNA
# Slc26a4
# Slc26a4
# KCNJ10 mRNA
# Slc26a4
# KCNJ10 protein
# Slc26a4
# KCNJ10 protein
# KCNJ10 K + channel
# Protein
# KCNJ10
# Slc26a4
# Slc26a4
# KCNJ10
# Slc26a4
# rRNA molecules
# Slc26a4
# rRNA molecules
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Slc26a4
# Pendrin
# Slc26a4
# ZO - 1
# ZO - 1
# Slc26a4
# K +
# Slc26a4
# K +
# K +
# K +
# Slc26a4
# K +
# Slc26a4
# K +
# proteins KCNQ1
# KCNE1
# SLC12A2
# K +
# GJB2
# Cx26
# K +
# K +
# diuretic
# Na +
# K +
# SLC12A2
# Slc26a4
# Slc26a4
# Slc26a4
# KCNQ1
# KCNE1
# K +
# Na +
# K +
# SLC12A2
# protein GJB2
# Slc26a4
# Slc26a4
# KCNQ1
# KCNE1 proteins
# KCNQ1 protein
# Slc26a4
# KCNQ1 mRNA
# K +
# K +
# Protein
# KCNQ1
# KCNE1
# SLC12A2
# GJB2
# Slc26a4
# Slc26a4
# pendrin
# K +
# Slc26a4
# KCNJ10 protein
# CO2
# HCO3 -
# free radicals
# CO2
# free radicals
# carbonic
# CO2
# HCO3 -
# catalase
# free radicals
# free radical
# glutathione
# melanin pigment
# pendrin
# HCO3 -
# HCO3 -
# free radical
# cysteine
# glutathione
# free radical
# pendrin
# free radical
# free radical
# KCNJ10 protein
# K +
# free radicals
# KCNJ10 K + channel
# Slc26a4
# KCNJ10
# pendrin
# Cys
# cysteine
# Glu
# glutamate
# Gly
# glycine
# carbonic
# GST
# glutathione - S - transferase
# GSH
# glutathione
# molecular
# K +
# pendrin
# Molecular
# PPAR delta
# peroxisome proliferator - activated receptor delta
# PPAR delta
# PPAR delta agonist
# molecularly
# ATP
# calcium
# Peroxisome proliferator - activated receptor - gamma coactivator 1 alpha
# PGC - 1 alpha
# insulin
# peroxisome proliferator - activated receptor ( PPAR ) delta
# long - chain fatty - acid
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR alpha
# PPAR delta
# PGC - 1 alpha
# protein
# PPAR delta
# amino - acid
# PPAR delta
# human alpha - skeletal actin
# PPAR delta
# PPAR delta
# PPAR delta
# protein
# PPAR delta
# PPAR delta protein
# PPAR delta
# PPAR delta
# myoglobin
# protein
# myoglobin
# mRNA
# myoglobin
# electron
# cytochrome c
# cytochrome c oxidase [ COX ] II and IV
# fatty - acid
# PPAR delta
# PGC - 1 alpha
# COXII
# proteins
# myoglobin
# cytochrome c and b
# protein troponin I ( slow )
# protein troponin I ( fast )
# PPAR delta
# PPAR delta
# agonist
# proteins
# PPAR delta
# PPAR delta
# oxygen
# glycogen
# triglyceride
# glucose
# PPAR delta agonist
# glucose
# PPAR delta agonist
# PPAR delta
# molecularly
# PPAR delta
# oxygen
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# proteins
# PPAR delta
# PPAR delta
# PGC - 1 alpha
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# fatty - acid
# Fatty acids
# metabolites
# PPAR delta
# PGC - 1 alpha
# PPAR delta
# PGC - 1 alpha
# PPAR delta
# PPAR delta
# PPAR delta
# molecular
# fatty - acid
# glucose
# glucose
# PPAR delta
# PPAR delta
# glucose
# insulin
# PPAR delta
# PPAR delta
# insulin
# PPAR delta
# molecular
# insulin
# amino acid residues
# residues
# mouse PPAR delta
# PPAR delta
# human alpha - skeletal actin
# chow
# PPAR delta
# chow
# compound
# protein
# proteins
# dye
# agarose
# alpha - skeletal actin
# Molecular
# mCPT1
# muscle carnitine palmitoyltransferase - 1 PGC - 1 alpha
# Peroxisome proliferator - activated receptor - gamma coactivator 1 alpha
# protein
# PPAR delta
# PPAR delta
# proteins
# PPAR delta
# PPAR delta
# proteins
# PPAR delta
# PPAR delta
# COXII
# MCIP1
# agarose
# PPAR delta agonist
# glycogen
# triglyceride
# Glucose
# glucose
# glucose
# PPAR delta Agonists
# Glucose
# glucose
# glucose
# PPAR delta
# PPAR delta
# PPAR delta
# PPAR delta
# reagents
# PPAR delta
# subunit c
# CLN3
# battenin
# mitochondrial ATP synthase , subunit c
# battenin
# MAP - 2
# NeuN
# battenin
# ATPase subunit c
# cathepsin D
# ATP
# battenin
# CLN3
# protein product
# subunit c of the mitochondrial ATP synthase complex
# subunit c
# CLN3
# protein
# battenin
# CLN3
# cln3 p
# protein
# Battenin
# btn1
# CLN3
# battenin
# amino acid
# battenin
# battenin
# subunit c
# mitochondrial subunit c
# SV40 large T antigen
# nestin
# GFAP
# SV40 large T antigen
# nestin
# MAP2
# NeuN
# calbindin
# nestin
# GFAP
# MAP2
# NeuN
# calbindin
# battenin
# Cln3 mRNA
# battenin protein
# molecular
# battenin
# Cln3 mRNA
# battenin
# Lamp1
# early endosome antigen 1
# EEA1
# Rab7
# transferrin receptor
# Lamp1
# EEA1
# Rab7
# Cln3 mRNA products
# Cln3 mRNA
# Cln3
# ethidium - bromide
# agarose
# Battenin
# Lamp 1
# EEA1
# Rab7
# EEA1
# Rab7
# Rab7
# Lamp 1
# EEA1
# Rab7
# Lamp 1
# Lamp 1
# EEA1
# Rab7
# subunit c
# subunit c
# subunit c
# electron
# Subunit c
# Subunit c
# subunit c
# subunit c
# subunit c
# subunit c protein
# protein
# subunit c protein
# sub c
# subunit c protein
# Protein
# cytochrome c oxidase subunit IV
# cox4
# electron
# electron
# cathepsin D
# subunit c
# cathepsin D
# ATP synthase subunit c
# cathepsin D
# cathepsin D
# unprocessed and processed cathepsin D
# cathepsin D
# cathepsin D
# cathepsin D
# Cathepsin D
# molecular
# cathepsin D
# Cathepsin D
# cathepsin D
# unprocessed and processed forms of cathepsin D protein
# Cathepsin D
# Cathepsin D
# cathepsin D
# cathepsin D
# subunit c
# cathepsin D
# protein
# protein
# cathepsin D
# cathepsin D
# protein disulfide isomerase
# PDI
# GM130
# VVL
# Lamp 2
# Lamp 1
# Lamp 1
# Lamp 2
# protein
# dye
# acidic
# Lamp 2
# Lamp 2
# dye
# Lamp 2
# dye
# early endosome marker
# EEA1
# FITC
# FITC
# FITC
# FITC
# FITC
# FITC
# subunit c
# protein
# grp75
# ATP
# hydrogen peroxide
# grp75
# ATP
# ATP
# ATP
# ATP
# hydrogen peroxide
# hydrogen peroxide
# H2O2
# H2O2
# battenin
# mitochondrial ATPase subunit c
# subunit c
# cathepsin D
# cathepsin D
# CLN3
# cathepsin D
# cathepsin B
# CLN2
# TPPI
# cathepsin D protein
# cathepsin D
# cathepsin D
# subunit c
# subunit c protein
# subunit c
# subunit c
# subunit c
# battenin
# proteins
# battenin
# Battenin
# battenin protein
# protein
# CLN3
# battenin protein
# battenin
# battenin
# battenin
# reagents Nestin
# Lamp 1
# Lamp 2
# subunit c
# GFAP
# calbindin
# SV40 T antigen
# cathepsin D
# cytochrome c oxidase subunit IV
# cox4
# PDI
# GM130
# grp75
# early endosome antigen - 1
# EEA1
# rab 7
# VVL
# biotin
# FITC
# Molecular
# Salt
# glucose
# EDTA
# DNase I
# ornithine
# CO2
# KCl
# large T antigen
# neomycin
# ornithine
# CO2
# alpha - FGF
# IBMX
# forskolin
# dopamine
# Cln3
# Subunit c
# protein
# formaldehyde
# phosphate buffered
# subunit c
# protein
# cacodylate
# formaldehyde
# methanol
# acetone
# glycine
# bovine serum albumin
# BSA
# BSA
# BSA
# proteins
# Tris
# protease inhibitors
# protein
# Protein
# SDS
# tris
# tricine SDS
# subunit c
# Cathepsin D
# protein
# Tris
# protein
# Protein
# protein
# cathepsin D
# Cathepsin D
# Molecular
# FITC
# dye
# formaldehyde
# ATP
# ATP
# Reagent
# ATP
# Hydrogen peroxide
# hydrogen peroxide
# hydrogen peroxide
# ATP
# subunit c of mitochondrial ATPase
# Electron
# cathepsin D
# TGF - beta 2
# Snail
# transforming growth factor beta 2
# Snail
# protein
# Snail
# E - cadherin
# proteins
# molecular
# bone morphogenic proteins
# BMPs
# transforming growth factor beta s
# TGF - beta s
# molecules
# effectors
# BMP
# noggin
# lymphoid enhancer factor - 1
# beta - catenin
# LEF - 1
# beta - catenin
# E - cadherin
# cadherin
# E - cadherin
# E - cadherin
# LEF - 1
# E - cadherin
# beta - catenin
# E - cadherin
# beta - catenin
# protein Ajuba
# zyxin
# proteins
# protein
# E - cadherin
# E - cadherin
# LEF - 1
# beta - catenin
# Snail
# Slug
# zinc
# proteins
# Snail
# E - cadherin
# E - cadherin
# cadherin
# Snail
# LEF - 1
# beta - catenin
# E - cadherin
# Snail
# E - cadherin
# Snail
# E - cadherin
# Snail
# mRNA
# BMP
# LEF - 1
# beta - catenin
# Snail
# TGF - beta 2
# small phenotype - and mothers against decapentaplegic - related protein 2
# SMAD2
# Snail
# TGF - beta 2
# Snail
# Snail
# Snail mRNA
# Protein
# Snail
# Snail
# Snail
# LEF - 1
# beta - catenin
# E - cadherin
# LEF - 1
# beta - catenin
# Snail
# Slug
# Snail mRNA
# Snail mRNA
# Snail
# Snail
# Snail mRNA
# Snail mRNA
# protein
# zinc
# proteins
# Snail protein
# Snail
# Snail
# Snail
# Snail
# protein
# Snail
# Snail
# Snail
# Snail protein
# Snail
# Snail
# Snail
# Ki67
# Snail
# Ki67
# Snail
# Ki67
# LEF - 1
# beta - catenin
# E - cadherin
# Snail
# Snail
# Snail
# Snail
# Snail
# K14
# Snail
# Snail
# Snail
# Snail protein
# Snail
# Ki67
# keratin 6
# Snail
# Snail
# keratin 5
# K5
# Snail
# Snail
# Snail protein
# K5
# Ki67
# Snail
# Snail
# Proteins
# Snail
# E - cadherin
# Snail
# E - cadherin
# Snail
# E - cadherin
# proteins
# Snail
# E - cadherin
# alpha - catenin
# proteins
# beta - catenin
# Ajuba
# beta - catenin
# Ajuba
# Snail protein
# E - cadherin
# alpha - catenin
# beta - catenin
# Ajuba
# alpha - catenin
# Snail
# E - cadherin
# alpha - catenin
# E - cadherin
# Snail
# Snail
# E - cadherin
# alpha - catenin
# E - cadherin
# E - cadherin protein
# alpha - catenin
# alpha - catenin
# Snail
# alpha - catenin
# E - cadherin
# mRNA
# proteins
# Snail
# proteins
# Snail
# E - cadherin
# Snail
# Snail
# E - cadherin
# Snail
# protein
# E - cadherin
# beta - catenin
# LEF - 1
# proteins
# cyclin D
# Snail
# beta - catenin
# beta - catenin
# Snail
# LEF - 1
# beta - catenin
# Ajuba
# Snail
# Ajuba
# growth factor receptor - bound protein - 2
# Grb - 2
# sevenless
# nucleotide
# Ajuba
# Snail
# Ajuba
# Grb - 2
# protein
# Snail
# alpha - catenin
# Grb - 2
# Ajuba
# protein
# alpha - catenin
# Snail
# E - cadherin
# alpha - catenin
# Ajuba
# Grb - 2
# Sos
# Grb - 2
# Sos
# alpha - catenin
# Ajuba
# Ajuba
# Ajuba
# K14
# inhibitor
# Ajuba
# Grb - 2
# alpha - catenin
# Snail
# Ajuba
# Grb - 2
# Snail
# Ajuba
# Grb - 2
# Ajuba
# proteins
# Snail
# Snail
# Snail
# Snail
# proteins
# proteins
# molecular
# Reagents
# E - cadherin
# beta - catenin
# Ajuba
# beta 4 integrin
# CD104
# K5
# loricrin
# involucrin
# fillagrin
# Grb - 2
# P - cadherin
# vimentin
# Ki67
# TGF - beta 2
# FITC
# Snail
# Snail
# GST
# human TGF - beta 2
# TGF - beta 2
# protein
# K14
# Snail
# mm Snail
# K14
# K14
# Smad 2
# TGF - beta 2
# shh
# Protein
# sodium deoxycholate
# Tris
# Cl
# NaCl
# sodium vanadate
# phenylmethylsulfonyl fluoride
# protease inhibitors
# nitrogen
# EDTA
# NaCl
# sodium deoxycholate
# SDS
# protease inhibitors
# Protein
# Protein
# Protein
# SDS
# reagent
# noggin
# Snail
# SMAD
# Snail
# Ajuba
# Snail
# digoxigenin
# dig
# Snail
# sodium citrate
# Snail
# Snail
# GAPDH
# GAPDH
# Snail
# TGF - beta 2
# K14
# Smad2
# reagents
# BMP
# bone morphogenic protein
# Grb - 2
# growth factor receptor - bound protein - 2
# K1
# keratin 1 K5
# keratin 5
# LEF - 1
# lymphoid enhancer factor - 1
# protein
# SMAD Shh
# sonic hedgehog SMADs
# small phenotype - and mothers against decapentaplegic - related proteins Sos
# son of sevenless
# TGF - beta
# transforming growth factor beta
# Snail
# compound
# Snail
# Snail
# Snail protein
# Protein
# K14
# K14
# Snail
# K14
# Snail
# proteins
# SDS
# Snail
# Snail protein
# Snail
# Snail
# Snail
# Ki67
# beta 4 int
# integrin beta 4
# E - cadherin
# E - cad
# E - cadherin
# Snail
# K14
# Snail
# K14
# Snail
# K14
# food
# Snail
# Snail
# keratin 5
# K5
# keratin 6
# Ki67
# Ki67
# Ki67
# Snail
# Snail
# Snail protein
# K5
# involucrin
# Inv
# protein
# loricrin
# Lor
# protein
# filaggrin
# Fil
# protein
# K5
# Snail
# Snail
# Snail protein
# proteins
# E - cadherin
# E - cad
# protein
# beta - catenin
# beta - cat
# E - cadherin
# LEF - 1
# proteins
# beta - catenin
# Ajuba
# zyxin
# Ajuba
# proteins
# Grb - 2
# GTP nucleotide
# protein
# Snail
# E - cad
# Ajuba
# beta - catenin
# Ajuba
# protein
# beta - catenin
# Ajuba
# protein
# P - cad
# P - cadherin
# protein
# E - cadherin
# alpha - catenin
# Snail
# Snail
# alpha - catenin
# E - cadherin
# Snail
# Snail
# Snail
# Ecad
# calcium
# calcium
# Snail
# E - cadherin
# Snail
# K14
# Snail
# Snail
# E - cad
# Snail
# E - cadherin protein
# Ajuba
# Grb - 2
# alpha - catenin
# Protein
# K14
# Snail
# K14
# alpha - catenin
# protein
# Grb - 2
# SDS
# Ajuba
# Grb - 2
# Ajuba
# alpha - catenin
# proteins
# Ajuba
# Grb - 2
# Ajuba
# K14
# K14
# Snail
# Ajuba
# Ajuba
# inhibitor
# Grb - 2
# Sos
# protein
# SDS
# Ajuba
# Snail
# TGF - beta 2
# noggin
# Snail
 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# insulin
# PGC - 1 alpha
# PGC - 1 alpha
# peroxisome proliferator - activated receptor - gamma ( PPAR gamma ) coactivator - 1 alpha
# PGC - 1 alpha
# molecular
# PGC - 1 alpha
# PPAR gamma
# PGC - 1 related coactivator
# PRC
# PGC - 1 beta
# PGC - 1 alpha
# PGC - 1 alpha
# ATP
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# mitochondrial uncoupling protein - 1
# UCP - 1
# hormone
# PPAR gamma
# PGC - 1 alpha
# nuclear respiratory factors 1
# NRF - 1
# mitochondrial transcription factor A
# Tfam
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# insulin
# human PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# neomycin
# murine PGC - 1 alpha
# amino acid
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha protein
# protein
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha proteins
# PGC - 1 beta
# PRC
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# food
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# Electron
# PGC - 1 alpha
# PGC - 1 alpha
# electron
# PGC - 1 alpha
# PGC - 1 alpha
# proteins
# electron
# cytochrome c
# cytochrome oxidase IV
# beta subunit of ATP synthase
# PGC - 1 alpha
# PGC - 1 alpha
# Tfam
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# ADP
# succinate
# oligomycin
# ATP
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# oxygen
# oxygen
# PGC - 1 alpha
# O2
# PGC - 1 alpha
# O2
# ATP
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# adrenergic - selective agonist
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# beta - adrenergic
# PGC - 1 alpha
# beta - adrenergic
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# lipid
# PGC - 1 alpha
# lipid
# Electron
# PGC - 1 alpha
# PGC - 1 alpha
# triglyceride
# UCP - 1
# protein
# UCP - 1
# PGC - 1 alpha
# UCP - 1 mRNA
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# UCP - 1
# PGC - 1 alpha
# beta 3 - adrenergic receptor
# oxygen
# beta 3 - adrenergic
# PGC - 1 alpha
# oxygen
# beta 3
# agonist
# PGC - 1 alpha
# PGC - 1 alpha
# beta 3 - adrenergic
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# fatty acid
# fatty acid
# PGC - 1 alpha
# PGC - 1 alpha
# electron
# triglyceride
# TAG
# triglycerides
# fatty acids
# PGC - 1 alpha
# Oleate
# PGC - 1 alpha
# lipid
# 3H
# palmitate
# PGC - 1 alpha
# PGC - 1 alpha
# oleate
# PGC - 1 alpha
# lipid
# lipid
# fatty acid
# PGC - 1 alpha
# PGC - 1 alpha
# fatty acid
# MCPT
# MCAD
# PGC - 1 alpha
# PGC - 1 alpha
# fatty acid
# PGC - 1 alpha
# sterol regulatory element binding protein - 1c
# SREBP - 1c
# SREBP - 1c
# stearoyl - CoA desaturase
# SCD1
# PGC - 1 alpha
# diglyceride acyltransferase
# DGAT
# TAG
# PGC - 1 alpha
# TAG
# PGC - 1 alpha
# 3H
# glycerol
# TAG
# 3H
# TAG
# PGC - 1 alpha
# PGC - 1 alpha
# TAG
# PGC - 1 alpha
# PGC - 1 alpha
# Insulin
# PGC - 1 alpha
# insulin
# PGC - 1
# insulin
# glucose
# insulin
# PGC - 1 alpha
# Glucose
# glucose
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# glucose
# insulin
# Glucose
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# glucose
# chow
# glucose
# PGC - 1 alpha
# PGC - 1 alpha
# chow
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# glucose
# insulin
# PGC - 1 alpha
# PGC - 1 alpha
# insulin
# PGC - 1 alpha
# glucose
# insulin
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# glial fibrillary acidic protein
# PGC - 1 alpha
# PGC - 1 alpha
# glial fibrillary acidic protein
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# fatty acid
# electron
# PGC - 1 alpha
# NRF - 1
# estrogen - related receptor alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# beta - adrenergic
# PGC - 1 alpha
# PGC - 1 alpha
# UCP - 1 mRNA
# adrenergic agonist
# oxygen
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# triglyceride
# palmitate
# PGC - 1 alpha
# lipid
# fatty acid
# PGC - 1 alpha
# PGC - 1 alpha
# fatty acid
# triglyceride
# SREBP - 1c
# SCD - 1
# proteins
# PGC - 1 alpha
# triglyceride
# PGC - 1 alpha
# fatty acid
# PGC - 1 alpha
# FXR
# triglyceride
# triglyceride
# fatty acids
# PGC - 1 alpha
# PGC - 1 alpha
# food
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# glucose
# insulin
# PGC - 1 alpha
# chow
# PGC - 1 alpha
# glucose
# insulin
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# insulin
# PGC - 1 alpha
# glucose
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# lipid
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# glucose
# protein
# phosphoenolpyruvate carboxykinase
# glucose - 6 - phosphatase
# PGC - 1 alpha
# PGC - 1 alpha
# insulin
# PGC - 1 alpha
# insulin
# PGC - 1 alpha
# insulin
# PGC - 1 alpha
# estrogen - related receptor alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# protein
# PGC - 1 alpha proteins
# PGC - 1 alpha protein
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - l alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# Neomycin
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# food
# protein
# water
# Food
# protein
# PGC - 1 beta
# PRC
# UCP - 1
# PGC - 1 alpha
# PGC alpha
# reagents
# reagents
# UCP - 1
# GAPDH
# succinate
# rotenone
# chloral hydrate
# EGTA
# MgCl2
# imidazole
# K
# MES
# taurine
# ATP
# PCr
# DTT
# EGTA
# MgCl2
# imidazole
# K
# MES
# taurine
# DTT
# BSA
# Oxygen
# ADP
# ADP
# cytochrome c
# ADP
# oligomycin
# oxygen
# O2
# O2
# Insulin
# glucose
# Glucose
# Insulin
# D - glucose
# human regular insulin
# glucose
# GLUCOSE
# Oxygen
# oxygen
# beta 3 - adrenergic
# oxygen
# electron
# sodium cacodylate
# osmium
# ethanol
# electron
# electron
# electron
# uranyl acetate
# lead citrate
# electron
# alcohol
# PGC - 1 alpha
# PGC - 1 alpha
# Fatty acid
# triglyceride
# Triglyceride
# Palmitate
# 3H
# palmitic acid
# protein
# succinate
# rotenone
# O2
# protein
# PGC - 1 alpha
# PGC - 1 alpha
# oxygen
# oxygen
# O2
# O2
# CO2
# water
# sodium
# beta 1 , beta 2 , and alpha 1 - adrenergic agonist
# sodium pentobarbital
# bicarbonate
# NaCl
# NaHCO3
# KCl
# CaCl2
# glucose
# insulin
# palmitate
# fatty acid
# BSA
# Hg
# Hg
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# Neomycin
# electron
# TAG
# PPAR gamma
# PRC
# PGC - 1 related coactivator SCD
# steroyl CoA desaturase SREBP
# sterol regulatory element binding protein
# TAG
# triglyceride Tfam
# mitochondrial transcription factor A UCP
# uncoupling protein
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 beta
# PRC
# Ethidium bromide
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# actin
# protein
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# protein
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# electron
# PGC - 1 alpha
# PGC - 1 alpha
# electron
# PGC - 1 alpha
# cytochrome C
# Cyto c
# ATP synthase beta
# Tfam
# cytochrome oxidase IV
# COX IV
# PGC - 1 alpha
# oxygen
# PGC - 1 alpha
# PGC - 1 alpha
# succinate
# rotenone
# ADP
# oligomycin
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# adrenergic agonist
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# UCP - 1
# UCP1
# Ethidium bromide
# Eth Br
# ribosomal RNA
# UCP - 1
# 36B4
# adrenergic agonist
# oxygen
# adrenergic agonist
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# lipid
# electron
# PGC - 1 alpha
# PGC - 1 alpha
# lipid
# TAG
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# BSA
# oleate
# BSA
# oleate
# 3H
# palmitate
# 3H
# palmitate
# PGC - 1 alpha
# PGC - 1 alpha
# BSA
# BSA
# oleate
# oleate
# BSA
# PGC - 1 alpha
# BSA
# PGC - 1 alpha
# PGC - 1 alpha
# BSA
# PGC - 1 alpha
# PGC - 1 alpha
# succinate
# rotenone
# PGC - 1 alpha
# TAG
# TAG
# glycerol
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# Glucose
# Insulin
# PGC - 1 alpha
# glucose
# PGC - 1 alpha
# PGC - 1 alpha
# chow
# PGC - 1 alpha
# PGC - 1 alpha
# chow
# glucose
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# PGC - 1 alpha
# mRNA
# GAPDH
# PGC - 1 alpha
# PGC - 1 alpha
# L - CPT I
# liver - type carnitine palmitoyltransferase
# MCAD
# medium - chain acyl - CoA dehydrogenase
# SREBP
# sterol regulatory element binding protein
# SCD
# steroyl - CoA desaturase
# FAS
# fatty acid synthase
# GPAT
# glycerol - 3 - phosphate acyltransferase
# DGAT
# diacylglycerol acyltransferase
# PGC - 1 alpha
# Annexin A7
# Annexin A7
# protein
# phospholipids
# Ca2 + - ions
# Ca2 +
# Ca2 +
# Annexin A7
# Annexin A7 protein
# Annexin A7
# Annexin A7
# Annexin A7
# protein
# Annexin A7
# Annexin A7
# glial fibrillary acidic protein
# GFAP
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# proteins
# phospholipids
# Ca2 +
# amino acid
# amino acids
# Ca2 +
# phospholipid
# proteins
# Annexin A7
# phospholipids
# Ca2 + - ions
# Annexin A7
# Annexin A7
# molecular
# Annexin A7
# protein
# Annexin A7
# Ca2 +
# Annexin A7
# Ca2 +
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# mRNA
# protein
# mRNA
# Annexin A7 mRNA
# beta - actin
# mRNA
# beta - actin
# protein
# Annexin A7
# Annexin A7
# annexin A7
# beta - actin
# Annexin A7
# Proteins
# SDS
# acrylamide
# protein
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# protein
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# GFAP
# Annexin A7
# GFAP
# Annexin A7
# Annexin A7
# Annexin A7
# GFAP
# GFAP
# Annexin A7
# GFAP
# Annexin A7
# molecular
# GFAP
# Annexin A7
# Annexin A7
# Annexin A7
# GFAP
# Annexin A7
# Annexin A7
# GFAP
# AnnexinA7
# Annexin A7
# GFAP
# Annexin A7 protein
# AnxA7
# AnxA7
# GFAP
# Annexin A7
# Annexin A7
# protein
# Annexin A7
# AnxA7
# Annexin A7
# AnxA7
# Annexin A7 protein
# AnxA7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# AnxA7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# GFAP
# AnnexinA7
# Annexin A7
# AnnexinA7
# AnxA7
# AnnexinA7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# molecular
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# molecular
# Annexin A7
# Annexin A7
# Annexin A7
# formaldehyde
# Methanol
# Annexin A7
# SDS
# Annexin A7
# Emerin
# LAP2
# Emerin
# Annexin A7
# Annexin A7
# Annexin A7
# Annexin A7
# Pch2p
# Rec8
# Rec8
# Rec8
# SYCP1
# Rec8
# Rec8
# Trip13
# Spo11
# Mei1
# REC8
# TRIP13
# Rec8
# Rec8
# Rec8
# Rec8
# PCH2
# RecA
# DMC1
# Trip13
# Dmc1
# Dmc1
# Dmc1
# Dmc1
# Dmc1
# RAD51
# DMC1
# H2AX
# Dmc1
# Trip13
# Dmc1
# Trip13
# Mei1
# Spo11
# Mei1
# Spo11
# Spo11
# Mei1
# Trip13
# Dmc1
# Trip13
# Rec8 Trip13
# RAD17
# SAE2
# PCH2
# ZIP1
# SAE2
# ZIP1
# SYCP1
# ZIP1
# RAD17
# Rad1
# mouse Pch2 ( Trip13
# TRIP13
# Trip13
# proteins
# SPO11
# MLH1
# RAD54
# RAD54
# RAD51
# TRIP13
# Pch2p
# PCH2
# RAD17
# SAE2
# TRIP13
# Pch2
# TRIP13
# SPO11
# MEI1
# TRIP13
# OA
# TRIP13
# TRIP13
# proteins
# TRIP13
# ClpA
# protein
# Trip13
# TRIP13
# Trip13
# Dmc1
# Trip13
# OA
# etoposide
# OA
# TRIP13
# TRIP13
# rat thyroid receptor beta ( THRB
# THRB
# TRIP13
# THRB
# THRB
# TRIP13
# THRB
# PCH2
# protein
# TRIP13
# TRIP13
# PCH2
# protein
# TRIP13
# Arabidopsis PCH2
# proteins
# PCH2
# PCH2
# PCH2
# PCH2
# PCH2
# Dot1
# PCH1 in yeast
# histone
# zip1
# dmc1
# RAD54
# DOT1
# PCH2
# TRIP13
# DOT1
# TRP53
# TRP63
# RAD24
# Trip13
# Trip13
# Trip13
# Trip13
# neomycin
# Trip13
# Trip13
# Trip13 protein
# Med31
# amino acids
# TRIP13
# SDS
# human TRIP13
# proteins
# SYCP3
# STAG3
# proteins
# RAD51
# MLH1
# MLH3
# RAD51
# SYCP3
# STAG3
# MLH1
# SCP3
# SYCP1
# REC8
# RAD51
# RAD51
# DMC1
# STAG3
# MLH3
# human MLH1
# TopBP1
# histone
# TRF2
# BLM
# Molecular
# OA
# OA
# OA
# CO2
# TRIP13
# Amino acid
# Mouse TRIP13
# PCH2
# Fluorophores
# Trip13
# TRIP13
# PCH2
# Spo11
# Pch2p
# OA
# okadaic acid

# %%
set(type_e)
# Out:
# {'B-Chemical',
#  'B-GENE',
#  'E-Chemical',
#  'E-GENE',
#  'I-Chemical',
#  'I-GENE',
#  'S-Chemical',
#  'S-GENE'}

# %% [markdown]
# # Pos Tagging

# %%
from pycorenlp import StanfordCoreNLP
nlp = StanfordCoreNLP('http://localhost:9000')
def pos_noun(sentence):
    sent2 = ""
    sent = sentence.replace("@", " ")
    res = nlp.annotate(sent, properties={'annotators': "pos", 'outputFormat': 'json'})
    res = res["sentences"][0]["tokens"]
    noun_list = []
    current_noun = []
    for word in res:
        print(word)
        if (word['pos'][0] == 'N'):
            current_noun.append(word['word'])
        elif(len(current_noun) != 0):
            n = "_".join(current_noun)
            sent2 = sent2 + " " + n + " " + word['word']
            current_noun = []
            noun_list.append(n)
        else:
            sent2 = sent2 + " " + word['word']
    return sent2, noun_list
 'pos': 'NN', 'before': ' ', 'after': ' '}
# {'index': 19, 'word': 'demonstrated', 'originalText': 'demonstrated', 'characterOffsetBegin': 114, 'characterOffsetEnd': 126, 'pos': 'VBD', 'before': ' ', 'after': ' '}
# {'index': 20, 'word': 'that', 'originalText': 'that', 'characterOffsetBegin': 127, 'characterOffsetEnd': 131, 'pos': 'IN', 'before': ' ', 'after': ' '}
# {'index': 21, 'word': 'the', 'originalText': 'the', 'characterOffsetBegin': 132, 'characterOffsetEnd': 135, 'pos': 'DT', 'before': ' ', 'after': ' '}
# {'index': 22, 'word': 'Cd22', 'originalText': 'Cd22', 'characterOffsetBegin': 136, 'characterOffsetEnd': 140, 'pos': 'NN', 'before': ' ', 'after': ' '}
# {'index': 23, 'word': 'locus', 'originalText': 'locus', 'characterOffsetBegin': 141, 'characterOffsetEnd': 146, 'pos': 'NN', 'before': ' ', 'after': ' '}
# {'index': 24, 'word': 'encoding', 'originalText': 'encoding', 'characterOffsetBegin': 147, 'characterOffsetEnd': 155, 'pos': 'VBG', 'before': ' ', 'after': ' '}
# {'index': 25, 'word': 'mCD22', 'originalText': 'mCD22', 'characterOffsetBegin': 156, 'characterOffsetEnd': 161, 'pos': 'NN', 'before': ' ', 'after': ' '}
# {'index': 26, 'word': 'is', 'originalText': 'is', 'characterOffsetBegin': 162, 'characterOffsetEnd': 164, 'pos': 'VBZ', 'before': ' ', 'after': ' '}
# {'index': 27, 'word': 'a', 'originalText': 'a', 'characterOffsetBegin': 165, 'characterOffsetEnd': 166, 'pos': 'DT', 'before': ' ', 'after': ' '}
# {'index': 28, 'word': 'single', 'originalText': 'single', 'characterOffsetBegin': 167, 'characterOffsetEnd': 173, 'pos': 'JJ', 'before': ' ', 'after': ' '}
# {'index': 29, 'word': 'copy', 'originalText': 'copy', 'characterOffsetBegin': 174, 'characterOffsetEnd': 178, 'pos': 'NN', 'before': ' ', 'after': ' '}
# {'index': 30, 'word': 'gene', 'originalText': 'gene', 'characterOffsetBegin': 179, 'characterOffsetEnd': 183, 'pos': 'NN', 'before': ' ', 'after': ' '}
# {'index': 31, 'word': 'of', 'originalText': 'of', 'characterOffsetBegin': 184, 'characterOffsetEnd': 186, 'pos': 'IN', 'before': ' ', 'after': ' '}
# {'index': 32, 'word': '<', 'originalText': '<', 'characterOffsetBegin': 187, 'characterOffsetEnd': 188, 'pos': 'JJR', 'before': ' ', 'after': ' '}
# {'index': 33, 'word': 'or', 'originalText': 'or', 'characterOffsetBegin': 189, 'characterOffsetEnd': 191, 'pos': 'CC', 'before': ' ', 'after': ' '}
# {'index': 34, 'word': '=', 'originalText': '=', 'characterOffsetBegin': 192, 'characterOffsetEnd': 193, 'pos': 'JJ', 'before': ' ', 'after': ' '}
# {'index': 35, 'word': '30', 'originalText': '30', 'characterOffsetBegin': 194, 'characterOffsetEnd': 196, 'pos': 'CD', 'before': ' ', 'after': ' '}
# {'index': 36, 'word': 'kb', 'originalText': 'kb', 'characterOffsetBegin': 197, 'characterOffsetEnd': 199, 'pos': 'NN', 'before': ' ', 'after': ' '}
# {'index': 37, 'word': '.', 'originalText': '.', 'characterOffsetBegin': 200, 'characterOffsetEnd': 201, 'pos': '.', 'before': ' ', 'after': ''}
# (' Southern_analysis on genomic DNA isolated from tissues and cell_lines from several mouse_strains using mCD22_cDNA demonstrated that the Cd22_locus encoding mCD22 is a single copy_gene of < or = 30 kb .',
#  ['Southern_analysis',
#   'DNA',
#   'tissues',
#   'cell_lines',
#   'mouse_strains',
#   'mCD22_cDNA',
#   'Cd22_locus',
#   'mCD22',
#   'copy_gene',
#   'kb'])
